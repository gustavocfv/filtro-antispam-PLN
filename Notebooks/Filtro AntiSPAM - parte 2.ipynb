# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
import re

# %% [markdown]
# # 1.Carregando os dados

# %%
dados = pd.read_csv("train_data (1).csv", sep=',', encoding='utf-8', low_memory=False)
dados
# Out:
#                                                                                                                                                  SMS  \
# 0     BOLETO REFERENTE AS PARCELAS EM ATRASO DO CONSÓRCIO PELO BB.COM VENCIMENTO PARA HOJE Ñ PODE HAVER QUEBRA NO ACORDO. BONATTO ADV 0800 606 3301.
# 1     050003DA0202|lcloud-apple-lnc.com/?iphone=VtBqROY .
# 2     060804CB5F0303|ps: //bancodobrasil.seguranca.gq
# 3     Atualizacao ainda nao foi executado em sua conta. Evite bloqueios, atualize agora! Acesse: www.avisobbsms.com
# 4     0608042BE40303|ps://bancodobrasil.seguranca.cf/
# ...                                               ...
# 5995  Host : RB_Bicanga Ip: 170.244.231.14 nao esta respondendo ao ping - 2019-04-19 22:30:23
# 5996  Host : RB§Bicanga Ip: 170.244.231.14 nao esta respondendo ao ping - 2019-07-05 05:05:17
# 5997  Host : RB§Bicanga Ip: 170.244.231.14 nao esta respondendo ao ping - 2019-07-15 17:35:17
# 5998  Host : RB_Bicanga Ip: 170.244.231.14 nao esta respondendo ao ping - 2019-08-02 02:20:20
# 5999  050003730201|Faça login no aplicativo OlympTrad?: 170.244.24.150, BR, David Cana
#
#         LABEL
# 0     blocked
# 1     blocked
# 2     blocked
# 3     blocked
# 4     blocked
# ...       ...
# 5995  ok
# 5996  ok
# 5997  ok
# 5998  ok
# 5999  ok
#
# [6000 rows x 2 columns]

# %% [markdown]
# # 2.Processamento de Linguagem Natural

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\gusta\anaconda3\lib\site-packages (3.4.5)
# Requirement already satisfied: six in c:\users\gusta\anaconda3\lib\site-packages (from nltk) (1.14.0)

# %%
from time import time

# %%
ti = time()

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gusta\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Lematizador para palavras em Portugues
nltk.download('rslp')
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     C:\Users\gusta\AppData\Roaming\nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# True

# %%
dados
# Out:
#                                                                                                                                                  SMS  \
# 0     BOLETO REFERENTE AS PARCELAS EM ATRASO DO CONSÓRCIO PELO BB.COM VENCIMENTO PARA HOJE Ñ PODE HAVER QUEBRA NO ACORDO. BONATTO ADV 0800 606 3301.
# 1     050003DA0202|lcloud-apple-lnc.com/?iphone=VtBqROY .
# 2     060804CB5F0303|ps: //bancodobrasil.seguranca.gq
# 3     Atualizacao ainda nao foi executado em sua conta. Evite bloqueios, atualize agora! Acesse: www.avisobbsms.com
# 4     0608042BE40303|ps://bancodobrasil.seguranca.cf/
# ...                                               ...
# 5995  Host : RB_Bicanga Ip: 170.244.231.14 nao esta respondendo ao ping - 2019-04-19 22:30:23
# 5996  Host : RB§Bicanga Ip: 170.244.231.14 nao esta respondendo ao ping - 2019-07-05 05:05:17
# 5997  Host : RB§Bicanga Ip: 170.244.231.14 nao esta respondendo ao ping - 2019-07-15 17:35:17
# 5998  Host : RB_Bicanga Ip: 170.244.231.14 nao esta respondendo ao ping - 2019-08-02 02:20:20
# 5999  050003730201|Faça login no aplicativo OlympTrad?: 170.244.24.150, BR, David Cana
#
#         LABEL
# 0     blocked
# 1     blocked
# 2     blocked
# 3     blocked
# 4     blocked
# ...       ...
# 5995  ok
# 5996  ok
# 5997  ok
# 5998  ok
# 5999  ok
#
# [6000 rows x 2 columns]

# %% [markdown]
# ## 2.1.Divisão em base treino e base teste para validação do modelo

# %% [markdown]
# Vamos separar a base de treino em 2 partes aleatórias, para validar o modelo que será desenvolvido. Para validar o modelo o mais rápido possível, vamos utilizar um simples train_test_split randômico. Se o modelo for aprovado, antes de colocar em produção, o ideal é treiná-lo novamente utilizando a técnica de K-Fold Validation para obter resultados mais robustos, sem dar chance para um possível viés advindo do train_test_split randômico.

# %%
import sklearn as sk

# %%
from sklearn.model_selection import train_test_split

# %%
dados_treino, dados_teste = train_test_split(dados, test_size=0.2, random_state=14, shuffle=True)

# %%
dados_treino
# Out:
#                                                                                                                                                                            SMS  \
# 3792  Faça login no aplicativo OlympTrad?: 131.72.109.159, BR, Embu-guacu
# 2980  Gruppem SIEM - Outbound cleartext password usage from non guest network detected (Destination IP: 104.44.18.195\r\r\n  Destination TCP/UDP Port: 11\r\r\n (SYSTAT)) Veri
# 2654  MARCIA, CPF 097.xxx.xxx-04, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858
# 3253  Sr.(a) KARLA,CPF 116.xxx.xxx-76, seu debito junto ao BRADESCO desde 15/09/2006 pode ser quitado hoje por R$600. Ligue agora 08006002934 /whatsapp 11997193858
# 1446  BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?GFQKE15S
# ...                                                                                            ...
# 3833  Roteador RadioScan Externo (132.255.248.169)\r\nDesligado as Jan 02 2019 10:20 PM (GMT -2:00)\r\nErro: ping: request timeout
# 2454  Estamos tentando contato com ALINE. Assunto de extrema importancia, CPF: 073-xxx.xxx-09 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508
# 1292  BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?F74F5SEG
# 5464  Faça login no aplicativo OlympTrad?: 168.121.182.0, BR, Mesquita
# 2667  060804BCAE0202|/0pt.us/1cRWRS4 .
#
#         LABEL
# 3792  ok
# 2980  ok
# 2654  ok
# 3253  ok
# 1446  blocked
# ...       ...
# 3833  ok
# 2454  ok
# 1292  blocked
# 5464  ok
# 2667  ok
#
# [4800 rows x 2 columns]

# %%
tamanho_base_treino = len(dados_treino)
tamanho_base_treino_ok = len(dados_treino[(dados_treino['LABEL'])=='ok'])
tamanho_base_treino_blocked = len(dados_treino[(dados_treino['LABEL'])=='blocked'])

porcentagem_ok = (tamanho_base_treino_ok * 100) / tamanho_base_treino
porcentagem_blocked = 100 - porcentagem_ok

print("A base treino tem {:.4}% de mensagens com classificação OK".format(porcentagem_ok))
print("A base treino tem {:.4}% de mensagens com classificação BLOCKED".format(porcentagem_blocked))
# Out:
# A base treino tem 75.27% de mensagens com classificação OK
# A base treino tem 24.73% de mensagens com classificação BLOCKED

# %%
dados_teste
# Out:
#                                                                                                                                                                   SMS  \
# 1848  Sr.(a) JAIRO,CPF 018.xxx.xxx-83, seu debito junto ao BRADESCO desde 25/11/2012 pode ser quitado hoje por R$1600. Ligue agora 08006002934 /whatsapp 11997193858
# 532   Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://lu.x-sms-santander.com/?5511981870490
# 5903  Faça login no aplicativo OlympTrad?: 170.233.180.207, BR, Turvo
# 1302  BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?Z0MY2DD8
# 787   BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?US16P1GQ
# ...                                                                                           ...
# 2501  CARLOS, CPF 077.xxx.xxx-35, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858
# 5319  -- ping (inativo) -- PING.NET_(Bruno) -- as 08:04:10. IP: 167.249.95.10
# 2505  CASA,CNPJ 07799.xxx/xxxx-00,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$15.51 valida ate 08/03. Ligue 08006002934 /whats 11997193858
# 5906  Faça login no aplicativo OlympTrad?: 170.233.206.46, BR, Areia Branca
# 1467  BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?B8B7W8LO
#
#         LABEL
# 1848  ok
# 532   blocked
# 5903  ok
# 1302  blocked
# 787   blocked
# ...       ...
# 2501  ok
# 5319  ok
# 2505  ok
# 5906  ok
# 1467  blocked
#
# [1200 rows x 2 columns]

# %%
tamanho_base_teste = len(dados_teste)
tamanho_base_teste_ok = len(dados_teste[(dados_teste['LABEL'])=='ok'])
tamanho_base_teste_blocked = len(dados_teste[(dados_teste['LABEL'])=='blocked'])

porcentagem_ok = (tamanho_base_teste_ok * 100) / tamanho_base_teste
porcentagem_blocked = 100 - porcentagem_ok

print("A base teste tem {:.4}% de mensagens com classificação OK".format(porcentagem_ok))
print("A base teste tem {:.4}% de mensagens com classificação BLOCKED".format(porcentagem_blocked))
# Out:
# A base teste tem 73.92% de mensagens com classificação OK
# A base teste tem 26.08% de mensagens com classificação BLOCKED

# %%
dados_treino.reset_index(drop=True, inplace=True)
dados_treino
# Out:
#                                                                                                                                                                            SMS  \
# 0     Faça login no aplicativo OlympTrad?: 131.72.109.159, BR, Embu-guacu
# 1     Gruppem SIEM - Outbound cleartext password usage from non guest network detected (Destination IP: 104.44.18.195\r\r\n  Destination TCP/UDP Port: 11\r\r\n (SYSTAT)) Veri
# 2     MARCIA, CPF 097.xxx.xxx-04, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858
# 3     Sr.(a) KARLA,CPF 116.xxx.xxx-76, seu debito junto ao BRADESCO desde 15/09/2006 pode ser quitado hoje por R$600. Ligue agora 08006002934 /whatsapp 11997193858
# 4     BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?GFQKE15S
# ...                                                                                            ...
# 4795  Roteador RadioScan Externo (132.255.248.169)\r\nDesligado as Jan 02 2019 10:20 PM (GMT -2:00)\r\nErro: ping: request timeout
# 4796  Estamos tentando contato com ALINE. Assunto de extrema importancia, CPF: 073-xxx.xxx-09 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508
# 4797  BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?F74F5SEG
# 4798  Faça login no aplicativo OlympTrad?: 168.121.182.0, BR, Mesquita
# 4799  060804BCAE0202|/0pt.us/1cRWRS4 .
#
#         LABEL
# 0     ok
# 1     ok
# 2     ok
# 3     ok
# 4     blocked
# ...       ...
# 4795  ok
# 4796  ok
# 4797  blocked
# 4798  ok
# 4799  ok
#
# [4800 rows x 2 columns]

# %%
dados_teste.reset_index(drop=True, inplace=True)
dados_teste
# Out:
#                                                                                                                                                                   SMS  \
# 0     Sr.(a) JAIRO,CPF 018.xxx.xxx-83, seu debito junto ao BRADESCO desde 25/11/2012 pode ser quitado hoje por R$1600. Ligue agora 08006002934 /whatsapp 11997193858
# 1     Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://lu.x-sms-santander.com/?5511981870490
# 2     Faça login no aplicativo OlympTrad?: 170.233.180.207, BR, Turvo
# 3     BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?Z0MY2DD8
# 4     BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?US16P1GQ
# ...                                                                                           ...
# 1195  CARLOS, CPF 077.xxx.xxx-35, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858
# 1196  -- ping (inativo) -- PING.NET_(Bruno) -- as 08:04:10. IP: 167.249.95.10
# 1197  CASA,CNPJ 07799.xxx/xxxx-00,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$15.51 valida ate 08/03. Ligue 08006002934 /whats 11997193858
# 1198  Faça login no aplicativo OlympTrad?: 170.233.206.46, BR, Areia Branca
# 1199  BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?B8B7W8LO
#
#         LABEL
# 0     ok
# 1     blocked
# 2     ok
# 3     blocked
# 4     blocked
# ...       ...
# 1195  ok
# 1196  ok
# 1197  ok
# 1198  ok
# 1199  blocked
#
# [1200 rows x 2 columns]

# %% [markdown]
# ## 2.2.Estruturação dos dados

# %% [markdown]
# Para facilitar todo o processo de criação do algoritmo de NLP, vamos estruturar os dados, transformando o dataframe numa lista de tuplas, com cada tupla contendo a mensagem e a classificação. Vamos criar uma função para isso, pois pode ser útil no decorrer do projeto.

# %%
def carregar_dados(dados):
    base = []
    for i in range(len(dados)):
        base.append((dados['SMS'].loc[i], dados['LABEL'].loc[i]))
    return base

# %%
base_treino = carregar_dados(dados_treino)

# %%
base_treino[0]
# Out:
# ('Faça login no aplicativo OlympTrad?: 131.72.109.159, BR, Embu-guacu', 'ok')

# %%
base_teste = carregar_dados(dados_teste)

# %%
base_teste[0]
# Out:
# ('Sr.(a) JAIRO,CPF 018.xxx.xxx-83, seu debito junto ao BRADESCO desde 25/11/2012 pode ser quitado hoje por R$1600. Ligue agora 08006002934 /whatsapp 11997193858',
#  'ok')

# %%
print("Tamanho base de treino: ", len(base_treino))
print("Tamanho base de teste: ", len(base_teste))
# Out:
# Tamanho base de treino:  4800
# Tamanho base de teste:  1200

# %% [markdown]
# ## 2.3.Pré-processamento

# %% [markdown]
# ### 2.3.1.Remoção de pontução

# %%
import string

# %%
def remover_pontuacao(base):
    """Essa função remove as pontuações da base.
    Args:
        base: contém as mensagens no formato (SMS,LABEL).
    Returns:
        base_dados: É uma lista de tuplas.
    """
    lista_final = []
    for (sms, label) in base:
        sem_pontuacao = []
        # Para cada palavra na mensagem        
        for p in sms:
            # Verifica se não é uma pontuação
            if p not in string.punctuation:
                sem_pontuacao.append(p)
        # Refaz a frase
        aux = ''.join(sem_pontuacao)
        # Salva na lista final no formato (sms,label)
        lista_final.append((aux.lower(), label))
    # Retorna todo o conjunto sem as pontuações
    return (lista_final)

# %%
print(base_treino[0])
# Out:
# ('Faça login no aplicativo OlympTrad?: 131.72.109.159, BR, Embu-guacu', 'ok')

# %%
print(remover_pontuacao([base_treino[0]]))
# Out:
# [('faça login no aplicativo olymptrad 13172109159 br embuguacu', 'ok')]

# %%
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
frases_sem_pontuacao = remover_pontuacao(base_treino)

# %%
print(frases_sem_pontuacao[0])
# Out:
# ('faça login no aplicativo olymptrad 13172109159 br embuguacu', 'ok')

# %% [markdown]
# ### 2.3.2.Remoção de Stop Words

# %% [markdown]
# As stopwords são palavras que não possuem significado para o desempenho dos algoritmos de classificação de texto. Por exemplo: 'é', 'muito', 'o', 'por', entre outros.
#
# A permanência delas na base de dados pode provocar maior lentidão no processamento dos dados, sem utilidade para o contexto em que estamos trabalhando.
#
# A função ```remover_stopwords``` funciona da seguinte forma:
#
# - O parâmetro "frases_sem_pontuacao" representa toda a base de dados já tratada.
# - Essa base de dados contém um par de elementos sendo o primeiro a frase e o segundo a classe (ok, blocked).
# - A função percorre toda a base de dados, linha a linha, verificando quais frases possuem as stopwords definidas na biblioteca NLTK. Uma vez identificadas, elas são removidas da frase.
# - O conjunto final é uma estrutura contendo a frase (sem as stopwords) e a classe (ok, blocked).

# %%
# Carrega as stopwords definidas na biblioteca para o idioma Português
stopwordsnltk = nltk.corpus.stopwords.words('portuguese')

# Visualiza algumas
print(stopwordsnltk[:10])
# Out:
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um']

# %%
def remover_stopwords(frases_sem_pontuacao):
    """Essa função remove as stopwords da base.
    Args:
        frases_sem_pontuacao: É uma lista de tuplas.
    Returns:
        frases_final: É uma lista de tuplas (frase, classe).
    """
    stopwordsnltk = nltk.corpus.stopwords.words('portuguese')
    frases_final = []
    for (frase, classe) in frases_sem_pontuacao:
        sem_stop = []
        for palavra in frase.split():
            if palavra not in stopwordsnltk:
                sem_stop.append(palavra)  
        frases_final.append((sem_stop, classe))
    return frases_final

# %%
frases_sem_stopwords = remover_stopwords(frases_sem_pontuacao)

# %%
print(frases_sem_stopwords[0])
# Out:
# (['faça', 'login', 'aplicativo', 'olymptrad', '13172109159', 'br', 'embuguacu'], 'ok')

# %% [markdown]
# ### 2.3.3.Remoção do Radical das palavras (stemming)

# %% [markdown]
# Stemming é uma técnica utilizada para reduzir a dimensionalidade dos dados na etapa de pré-processamento. É baseada na redução de palavras em seu morfema, de acordo com as regras do idioma que o algoritmo será executado.
#
# Por exemplo, em português a palavra “casa” possui o morfema “cas” e suas variações: casinhas, casebre, casona.
#
# A função ```aplicar_stemmer``` funciona da seguinte forma:
#
# - Utiliza-se uma ferramenta da biblioteca NLTK para realizar essa técnica. Para isso, acessamos o pacote ```stem``` para realizar essa tarefa.
# - ```nltk.stem.RSLPStemmer()``` indica que será utilizado a lingua portguesa.
# - O parâmetro ```frases_sem_stopwords``` da função ```aplicar_stemmer``` representa a base de dados sem as stopwords que foram removidas anteriormente.
# - A função percorre toda a base de dados aplicando o método ```stemmer.stem(palavra)``` em cada palavra de cada frase, cuja finalidade é deixar apenas o radical de cada palavra.
#
# Uma desvantagem da aplicação do algoritmo stemmer é quando duas palavras com sentidos diferentes possuem o mesmo radical, como por exemplo as palavras ```novamente``` e ```novo``` que possuem o radical ```nov``` dessa forma, na etapa de aprendizado de máquina o algoritmo pode perder algumas nuances.

# %%
def aplicar_stemmer(frases_sem_stopwords):
    """Função que reduz a palavra ao seu radical
    Args:
        frases_sem_stopwords: lista de tuplas.
    Returns:
        frases_stemming: lista de tuplas.
    """
    stemmer = nltk.stem.RSLPStemmer()
    frases_stemming =[]
    for (frase, classe) in frases_sem_stopwords:
        com_stemming = []
        # Para cada palavra na frase, aplicar o stemmer e salvar
        for palavra in frase:
            com_stemming.append(str(stemmer.stem(palavra)))
        frases_stemming.append((com_stemming, classe))    
    # Retornar todo o conjunto com o stemming aplicado
    return frases_stemming

# %%
frases_com_stemmer = aplicar_stemmer(frases_sem_stopwords)

# %%
print(frases_com_stemmer[0])
# Out:
# (['faç', 'login', 'aplic', 'olymptrad', '13172109159', 'br', 'embuguacu'], 'ok')

# %% [markdown]
# ### 2.3.4.Lista de todas as palavras

# %% [markdown]
# A função ```extrair_palavras``` irá gerar uma nova lista com todas as palavras que já foram pré-processadas anteriormente porém sem a sua classificação (ok, blocked) associada.
#
# Funciona da seguinte forma:
# - O parâmetro da função representa a lista gerada pela função aplicar_stemmer, que é a ```frases_com_stemmer```.
# - Ela percorre toda a base e insere em uma lista com todas as palavras da base de dados, mas sem sua classificação associada.

# %%
def extrair_palavras(frases_com_stemmer):
    """Função que unifica todas as palavras do conjunto de dados em uma única lista.
    Args:
        frases_com_stemmer: Frases com o Stemmer já aplicados.
    Returns:
        todas_palavras: lista com todas as palavras.
    """
    todas_palavras = []
    for (palavras, classe) in frases_com_stemmer:
        todas_palavras.extend(palavras)
    return todas_palavras

# %%
palavras_sem_classe = extrair_palavras(frases_com_stemmer)

# %%
palavras_sem_classe[:10]
# Out:
# ['faç',
#  'login',
#  'aplic',
#  'olymptrad',
#  '13172109159',
#  'br',
#  'embuguacu',
#  'grupp',
#  'si',
#  'outbound']

# %% [markdown]
# ### 2.3.5.Medição de frequência de palavras únicas

# %% [markdown]
# Com a função ```aplicar_frequencia``` iremos remover os radicais repetidos da base para otimizar o processamento dos dados utilizando o recurso do nltk ```FreqDist```.
#
# A classe ```FreqDist``` unifica todas as palavras repetidas gerando um dicionário do tipo ```chave,valor``` dentro de uma lista, sendo a chave o radical e o valor a frequencia com que ele se repete. Ex: ```('am', 4)```. Nesse exemplo o radical ```am``` apareceu na base de dados 4 vezes.

# %%
def aplicar_frequencia(palavras_sem_classe):
    """Função que aplica a frequencia das palavras
    Args:
        palavras_sem_classe: palavras sem a classificação.
    Returns:
        palavras: FreqDist
    """
    palavras = nltk.FreqDist(palavras_sem_classe)
    return palavras

# %%
frequencia_palavras = aplicar_frequencia(palavras_sem_classe)

# %%
print(frequencia_palavras.most_common(50))
# Out:
# [('login', 1317), ('olymptrad', 1289), ('br', 1132), ('aplic', 1113), ('acess', 989), ('faç', 886), ('lig', 845), ('senh', 799), ('cpf', 795), ('debit', 761), ('bb', 707), ('evit', 630), ('quit', 609), ('08006002934', 609), ('11997193858', 609), ('what', 593), ('contat', 532), ('transtorn', 505), ('informavalid', 504), ('agor', 495), ('ate', 484), ('p', 478), ('ip', 466), ('junt', 408), ('brad', 407), ('refer', 348), ('val', 348), ('0803', 337), ('hoj', 303), ('telefon', 278), ('pod', 275), ('tent', 271), ('r', 262), ('inform', 260), ('whatsapp', 256), ('assunt', 256), ('extrem', 256), ('importanc', 256), ('11976509508', 256), ('lanc', 249), ('propost', 249), ('ping', 213), ('nov', 197), ('voc', 196), ('j', 181), ('expir', 181), ('valid', 181), ('proprietari', 172), ('div', 167), ('renegociaca', 165)]

# %% [markdown]
# ### 2.3.6.Extração das palavras únicas

# %% [markdown]
# Vamos criar uma estrutura apenas com as palavras únicas da frequência gerada anteriormente, utilizando a função ```extrair_palavras_unicas```.

# %%
def extrair_palavras_unicas(frequencia_palavras):
    """Função que retorna as palavras únicas
    Args:
        frequencia_palavras: dicionário com a frequencia das palavras.
    Returns:
        freq: palavras únicas.
    """
    freq = frequencia_palavras.keys()
    return freq

# %%
palavras_sem_repeticao = extrair_palavras_unicas(frequencia_palavras)

# %%
print(list(palavras_sem_repeticao)[:5])
# Out:
# ['faç', 'login', 'aplic', 'olymptrad', '13172109159']

# %% [markdown]
# ### 2.3.7.Extração de palavras de cada frase

# %% [markdown]
# O objetivo da função ```criar_caracteristicas``` é auxiliar a caracterização das frases a serem utilizadas no algoritmo Naive Bayes.
#
# O método ```nltk.classify.apply_features``` realiza essa caracterização através do mapeamento de cada frase na função ```criar_caracteristicas```. O resultado desse mapeamento é um dicionário para cada frase onde as palavras que pertencem a respectiva frase sejam ```True```. Todas as outras palavras da base que não pertencem a frase serão definidas como ```False```.
#
# O método ```nltk.classify.apply_features``` exige dois parâmetros, sendo o primeiro uma função que irá extrair as caracteristicas e o segundo é o conjunto de dados onde será aplicado essa caracterização.
#
# Essa etapa é necessária para a preparação da base de dados para o algoritmo de aprendizagem de máquina Naive Bayes. É o resultado dessa função que irá ser passada como parâmetro para criar o classificador.
#
# A função ```criar_caracteristicas``` recebe a lista com as palavras com o stemming e cria uma estrutura onde apenas as palavras que estão nessa lista será marcada como ```True```, todas as outras serão marcadas como ```False```.

# %%
def criar_caracteristicas(documento):
    """Função que cria as características do documento, verificando se a palavra existe ou não no documento.
    Args:
        documento: lista com todas as palavras
    Returns:
        caracteristicas: dicionário com as características.
    """
    global palavras_sem_repeticao
    doc = set(documento)
    caracteristicas = {}
    # Para cada palavra
    for palavra in palavras_sem_repeticao:
        # Se a palavra existir no documento é atribuido True, caso contrário False.
        caracteristicas[palavra] = (palavra in doc)    
    # Dicionário com as caracteristicas da palavra
    return caracteristicas

# %%
# Para testar a função acima, serão utilizadas duas frases com o stemmer já aplicado.
teste_caracteristica = frases_com_stemmer[0:2]

# %%
print(teste_caracteristica)
# Out:
# [(['faç', 'login', 'aplic', 'olymptrad', '13172109159', 'br', 'embuguacu'], 'ok'), (['grupp', 'si', 'outbound', 'cleartext', 'password', 'usag', 'from', 'non', 'guest', 'network', 'detected', 'destination', 'ip', '1044418195', 'destination', 'tcpudp', 'port', '11', 'systat', 'ver'], 'ok')]

# %%
print(extrair_palavras(teste_caracteristica))
# Out:
# ['faç', 'login', 'aplic', 'olymptrad', '13172109159', 'br', 'embuguacu', 'grupp', 'si', 'outbound', 'cleartext', 'password', 'usag', 'from', 'non', 'guest', 'network', 'detected', 'destination', 'ip', '1044418195', 'destination', 'tcpudp', 'port', '11', 'systat', 'ver']

# %% [markdown]
# A execução ```nltk.classify.apply_features``` irá gerar uma lista, onde cada elemento dessa lista é uma tupla com dois elementos, sendo o primeiro o dicionário gerado pela função ```criar_caracteristicas``` e o segundo elemento com a classificação (ok, blocked).

# %%
frases_teste_final = nltk.classify.apply_features(criar_caracteristicas, teste_caracteristica)

# %%
# Visualizar 1 elemento classificado
print(frases_teste_final[0])
# Out:
# ({'faç': True, 'login': True, 'aplic': True, 'olymptrad': True, '13172109159': True, 'br': True, 'embuguacu': True, 'grupp': False, 'si': False, 'outbound': False, 'cleartext': False, 'password': False, 'usag': False, 'from': False, 'non': False, 'guest': False, 'network': False, 'detected': False, 'destination': False, 'ip': False, '1044418195': False, 'tcpudp': False, 'port': False, '11': False, 'systat': False, 'ver': False, 'marc': False, 'cpf': False, '097xxxxxx04': False, 'condica': False, 'excepc': False, 'aprov': False, 'p': False, 'quit': False, 'debit': False, 'junt': False, 'brad': False, 'lig': False, 'agor': False, '08006002934': False, 'wpp': False, '11997193858': False, 'sra': False, 'karlacpf': False, '116xxxxxx76': False, 'desd': False, '15092006': False, 'pod': False, 'ser': False, 'hoj': False, 'r600': False, 'whatsapp': False, 'bb': False, 'informavalid': False, 'senh': False, 'evit': False, 'transtorn': False, 'acess': False, 'wwwbbrasildesbloqueiocomgfqke15': False, 'bitnuvemcom': False, 'identific': False, '1382042545': False, 'cont': False, 'nao': False, 'conhec': False, 'atualiz': False, 'imediat': False, 'israel': False, 'voc': False, 'nov': False, 'fot': False, 'httpfotosmsxyzcdi6e3nepqxp4': False, 'tent': False, 'contat': False, 'ana': False, 'assunt': False, 'extrem': False, 'importanc': False, '032xxxxxx19': False, 'telefon': False, '1127393055': False, 'what': False, '11976509508': False, 'banc': False, 'santand': False, 'prezado': False, 'client': False, 'bloquei': False, 'carta': False, 'refac': False, 'operaca': False, 'httpbcxsmssantandercom5511985866210': False, 'centrocnpj': False, '05977xxxxxxx62propost': False, 'refer': False, 'capit': False, 'gir': False, 'r8662': False, 'val': False, 'ate': False, '0803': False, '050003780201f': False, '138204235118': False, 'cab': False, 's': False, '131021714': False, 'sao': False, 'paul': False, 'wwwbbrasildesbloqueiocomav46qrzk': False, 'joanacnpj': False, '02587xxxxxxx44propost': False, 'renegociaca': False, 'div': False, 'r8292': False, 'elian': False, 'propriatari': False, '142xxxxxx09': False, 'ca': False, 'mastercard': False, 'r': False, '272021': False, 'lanc': False, 'propost': False, 'gratil': False, '08006002628': False, 'abc': False, 'is': False, 'down': False, '1': False, '25': False, 'pm': False, 'brst': False, 'reason': False, 'read': False, 'tim': False, 'out': False, 'location': False, 'br14816322012miam': False, 'us1992018955ri': False, 'jan': False, 'br18': False, 'abraa': False, '116xxxxxx63': False, '389672': False, 'respond': False, 'cust': False, 'jeffersoncnpj': False, '01571xxxxxxx58propost': False, 'r12384': False, 'httpbrxsmssantandercom5511986853151': False, '1032052678': False, 'kh': False, 'phnom': False, 'penh': False, 'serv': False, 'ping': False, 'disposi': False, 'estaca': False, 'glor': False, 'dalp': False, 'ap': False, 'basebox': False, '1001001614': False, 'pass': False, 'statu': False, 'ip1001001614': False, 'sistem': False, 'horari': False, 'comerc': False, 'sip': False, '17023112129': False, 'hor': False, '21042019': False, '165121': False, 'corre': False, '0500033a0201f': False, '14325553207': False, 'raimun': False, '131031140': False, 'maca': False, '170244152130': False, 'fri': False, 'wwwbbrasildesbloqueiocomakadlrxb': False, 'wwwbbrasildesbloqueiocomutfdl28': False, 'ei': False, 'francisc': False, '003xxxxxx10': False, 'sair': False, 'restrica': False, '5': False, 'dia': False, 'garant': False, 'melhor': False, 'negociaca': False, 'carat': False, 'exceca': False, '08002759600': False, 'inform': False, '24hr': False, 'httpsgooglwqekgq': False, 'dad': False, 'wwwbbrasildesbloqueiocompqa925z': False, 'fornec': False, 'const': False, 'sicaf': False, 'cnpj10118717855': False, 'venc': False, 'renov': False, 'wwwesicafwebcombr': False, '011': False, '21220202': False, 'leonard': False, 'viv': False, 'bom': False, 'marcel': False, 'seg': False, 'email': False, 'leonardobuenoctrendscombr': False, 'grat': False, 'j ...

# %% [markdown]
# Para facilitar a reutilização de todo o código criado anteriormente, iremos criar uma função para estruturar qualquer texto que desejamos classificar.

# %%
def estruturar_dados(base):
    """Dada uma base de dados, é realizada toda a estruturação das bases.
    Args:
        base: contém todas as mensagens no formato (SMS,LABEL).
    Returns:
        base_final: conjunto de dados estruturados.
    """
    global palavras_sem_repeticao
    # Aplicar as funções previamente definidas
    frases_sem_pontuacao = remover_pontuacao(base)
    frases_sem_stopwords = remover_stopwords(frases_sem_pontuacao)
    frases_com_stemmer = aplicar_stemmer(frases_sem_stopwords)
    palavras_sem_classe = extrair_palavras(frases_com_stemmer)
    frequencia_palavras = aplicar_frequencia(palavras_sem_classe)
    palavras_sem_repeticao = extrair_palavras_unicas(frequencia_palavras)
    base_final = nltk.classify.apply_features(criar_caracteristicas, frases_com_stemmer)
    # Retornar os dados estruturados para serem utilizados pela função NLTK.
    return (base_final)

# %% [markdown]
# # 3.Treino do algoritmo Naive Bayes

# %% [markdown]
# Nesta etapa, será realizado o treino do algoritmo Naive Bayes, que irá gerar um modelo a ser utilizado na classificação de novas frases em ok ou blocked.

# %% [markdown]
# ## 3.1.Classificação do texto

# %% [markdown]
# O algoritmo de Naive Bayes realiza a análise estatística e monta uma tabela de probabilidade. Após isso, é criada a classificação dos registros.
#
# O método ```train``` da classe ```NaiveBayesClassifier``` recebe como parâmetro a ```base_treino``` já estruturada (```base_final```) e realiza a etapa de construção da tabela de probabilidades. O método ```show_most_informative_features``` retorna os atributos (palavras) mais significativos.
#
# Por exemplo:
#
# - ```dia = True ok : blocke = 2.3:1.0``` - Neste exemplo de saída a probabilidade de a frase ser classificada como ```ok``` quando a palavra "dia" estiver presente na frase (```True```) é 2.3 vezes maior do que blocked.
#
# - ```am = False blocke : ok = 1.6:1.0``` - Já neste exemplo, a probabilidade de a frase ser classificada como ```blocked``` quando a palavra ```am``` **não** estiver presente na frase (```False```) é 1.6 vezes maior do que ok.

# %%
base_treino
# Out:
# [('Faça login no aplicativo OlympTrad?: 131.72.109.159, BR, Embu-guacu', 'ok'),
#  ('Gruppem SIEM - Outbound cleartext password usage from non guest network detected (Destination IP: 104.44.18.195\r\r\n  Destination TCP/UDP Port: 11\r\r\n (SYSTAT)) Veri',
#   'ok'),
#  ('MARCIA, CPF 097.xxx.xxx-04, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Sr.(a) KARLA,CPF 116.xxx.xxx-76, seu debito junto ao BRADESCO desde 15/09/2006 pode ser quitado hoje por R$600. Ligue agora 08006002934 /whatsapp 11997193858',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?GFQKE15S',
#   'blocked'),
#  ('bitnuvem.com: Identificamos acesso do IP 138.204.25.45 na sua conta. Nao conhece esse IP? Acesse sua conta e atualize sua senha imediatamente.',
#   'ok'),
#  ('Israel, Voce tem uma nova foto http://fotosms.xyz/c/d?i=6E3NEpQxp4',
#   'blocked'),
#  ('Estamos tentando contato com ANA. Assunto de extrema importancia, CPF: 032-xxx.xxx-19 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://bC.x-sms-santander.com/?5511985866210',
#   'blocked'),
#  ('CENTRO,CNPJ 05977.xxx/xxxx-62,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$86.62 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('050003780201|Faça login no aplicativo OlympTrad?: 138.204.235.118, BR, Cabo De S',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 131.0.217.14, BR, Sao Paulo', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?AV46QRZK',
#   'blocked'),
#  ('JOANA,CNPJ 02587.xxx/xxxx-44,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$82.92 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('ELIANE, propriatario do CPF 142xxx.xxx-09, seu c&a mastercard e de R$ 2720,21, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('ABC is Down from 1 25 PM BRST . Down reason , Read time out. Down from location Sao Paulo - BR(148.163.220.12),Miami - US(199.201.89.55),Rio de Janeiro - BR(18',
#   'ok'),
#  ('ABRAAO, propriatario do CPF 116xxx.xxx-63, seu cartao c&a e de R$ 3896,72, lance sua proposta! Responda sem custo.',
#   'ok'),
#  ('JEFFERSON,CNPJ 01571.xxx/xxxx-58,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$123.84 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://br.x-sms-santander.com/?5511986853151',
#   'blocked'),
#  ('OlympTrad? login: 103.205.26.78, KH, Phnom Penh', 'ok'),
#  ('O servico ping no dispositivo ESTACAO GLORIA - DALP - AP - BASEBOX - IP 100.100.16.14 passou para o status down - IP=100.100.16.14',
#   'ok'),
#  ('Tentativa ou Acesso ao Sistema Fora do horario Comercial / Login: sipi / IP: 170.231.121.29 / Hora: 21/04/2019 16:51:21 | SIPI CORRETOR.',
#   'ok'),
#  ('0500033A0201|Faça login no aplicativo OlympTrad?: 143.255.53.207, BR, Sao Raimun',
#   'ok'),
#  ('OlympTrad? login: 131.0.31.140, BR, Macae', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 170.244.152.130, BR, Cabo Frio', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?AKADLRXB',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?UTFDL28A',
#   'blocked'),
#  ('Ei, Francisco, seu CPF 003-xxx.xxx-10 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('Informa: Prezado(a) cliente, evite o bloqueio da sua conta, em ate 24hrs acesse: https://goo.gl/wqEkgQ e atualize seus dados.',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?PQA925ZA',
#   'blocked'),
#  ('Fornecedor, Consta no SICAF, o CNPJ(101.187.178.55) está vencido. Para renovar, Acesse : www.e-sicafweb.com.br ou (011) 2122-0202',
#   'ok'),
#  ('LEONARDO VIVO: Bom dia Marcelo segue meu email: leonardo.bueno@C-trends.com.br. Grato.',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?U361I5MY',
#   'blocked'),
#  ('Ei, Ana, seu CPF 041-xxx.xxx-10 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('0500030B0201|Faça login no aplicativo OlympTrad?: 138.94.176.251, BR, Aguas Lind',
#   'ok'),
#  ('OlympTrad? login: 118.173.233.149, TH, Bang Khen', 'ok'),
#  ('CODEVASF: Codigo otWt. Validade 23/04/2019 17:41. Origem 138.0.23.39, 35.199.62.54.',
#   'ok'),
#  ('Servmar:New Public IP: 152.243.101.236', 'ok'),
#  ('Sr.(a) ADAUTO,CPF 036.xxx.xxx-92, seu debito junto ao BRADESCO desde 08/11/2011 pode ser quitado hoje por R$1200. Ligue agora 08006002934 /whatsapp 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.205.50.1, BR, Barra Do Bugres',
#   'ok'),
#  ('ANDERSON, CPF 018.xxx.xxx-67, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Estamos tentando contato com HERNANDES. Assunto de extrema importancia, CPF: 089-xxx.xxx-10 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?0Y3W7HF6',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?5E4HD9PS',
#   'blocked'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?OWB1LE3H',
#   'blocked'),
#  ('0500032E0201|Faça login no aplicativo OlympTrad?: 170.150.226.149, BR, Ferraz De',
#   'ok'),
#  ('ANA, CPF 130.xxx.xxx-94, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Estamos tentando contato com WALDIR. Assunto de extrema importancia, CPF: 124-xxx.xxx-34 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 170.233.123.154, BR, Natal', 'ok'),
#  ('050003120201|Faça login no aplicativo OlympTrad?: 138.117.167.142, BR, Estrela D',
#   'ok'),
#  ('S,CNPJ 03509.xxx/xxxx-20,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$218.52 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 126.54.115.88, JP, Gifu', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.197.155.104, BR, Capitao Poco',
#   'ok'),
#  ('Gruppen SIEM - Outbound cleartext password usage from non guest network detected (Destination IP: 152.255.140.51\r\r\n  Destination TCP/UDP Port: 11\r\r\n (SYSTAT)) Ver',
#   'ok'),
#  ('ALERTA FREE:resolva oneline em  nosso canal:http://ritabolos.com.br/SpryAssets/freern/',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 131.161.38.148, BR, Poxoreu', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?RZ3S5Y30',
#   'blocked'),
#  ('Estamos tentando contato com ADILSON. Assunto de extrema importancia, CPF: 077-xxx.xxx-26 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('ALESSANDRA, proprietario do CPF 126.xxx.xxx-02, seu debito atual junto ao Bradesco e de R$ 5795,29, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('Estamos tentando contato com SUSIE. Assunto de extrema importancia, CPF: 015-xxx.xxx-84 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('CHARLES, CPF 032.xxx.xxx-28, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('-- ping (ativo) -- ASTERISK1 -- as 16:17:26. IP: 131.255.124.3', 'ok'),
#  ('C,CNPJ 01319.xxx/xxxx-41,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$205.25 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Ei, Adriana, seu CPF 051-xxx.xxx-07 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('CATTAN Informa: ATENCAO! Seu acordo vence amanha, efetue o pagamento.Duvidas,Contate a MALTA no 08006048080.Se pago, desconsidere.',
#   'ok'),
#  ('ZoomNet:Host : Backbone Oitis Ip: 131.255.34.2 nao esta respondendo ao ping - 2019-02-24 12:52:01',
#   'ok'),
#  ('EMPREITEIRA,CNPJ 00593.xxx/xxxx-54,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$95.03 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Celis, Voce tem uma nova foto http://fotosms.xyz/c/d?i=5Ha2ps8jHx',
#   'blocked'),
#  ('Segue email para solicitar autorizaÃ§Ã£o: msaude@memorial-saude.com.br',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 170.233.148.141, BR, Maraba', 'ok'),
#  ('Wilmaaaa, Voce tem uma nova foto http://fotosms.xyz/c/d?i=1Gzusr8DC8',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 164.163.32.33, BR, Trindade', 'ok'),
#  ('IP,123456,165.227.66.59,7099', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 131.161.227.2, BR, Fortaleza', 'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?UJ0YHEDI',
#   'blocked'),
#  ('Support Apple. Se requiere verifique  su  ID de Apple, visite el siguiente enlace para mas detalles:  http://icloudfind-support.com/HNTW9sG . ',
#   'blocked'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://qE.x-sms-santander.com/?5511986169096',
#   'blocked'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://AU.x-sms-santander.com/?5511987825219',
#   'blocked'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_Nagel NetIndisponivel\r\r\nIP: 138.99.22.46\r\r\nIniciou em: 2019.02.06 as 11:02:33',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?WOTOA0BZ',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?E8JQHJ57',
#   'blocked'),
#  ('050003460201|Faça login no aplicativo OlympTrad?: 138.204.113.34, BR, Francisco ',
#   'ok'),
#  ('Gruppen SIEM - Outbound cleartext password usage from non guest network detected (Destination IP: 152.255.132.148\r\r\n  Destination TCP/UDP Port: 11\r\r\n (SYSTAT)) Ve',
#   'ok'),
#  ('All Net: poplevel3-mkt-rb1016ccr DOWN CRITICAL - Time to live exceeded (11.11.12.66) Fri Jan 25 18:22:52 BRST 2019',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?ZGZZ1844',
#   'blocked'),
#  ('Host :NWT Ip: 138.121.136.18 voltou a respondendo ao ping - 2019-07-29 22:40:02',
#   'ok'),
#  ('Gruppen SIEM - Outbound cleartext password usage from non guest network detected (Destination IP: 152.255.140.45\r\r\n  Destination TCP/UDP Port: 11\r\r\n (SYSTAT)) Ver',
#   'ok'),
#  ('-- ping (ativo) -- ASTERISK1 -- as 10:55:55. IP: 131.255.124.3', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?BOQWZGKP',
#   'blocked'),
#  ('bitnuvem.com: Identificamos acesso do IP 138.186.27.12 na sua conta. 06/08 16:39',
#   'ok'),
#  ('Ei, Adao, seu CPF 023-xxx.xxx-01 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('ALLANA, CPF 093.xxx.xxx-93, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('PingdomAlert DOWN: OVH - Bazelgeuse - Servidor Ernas (142.44.178.175) is DOWN since 23/08/2019  00:35:16.',
#   'ok'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_BRNetIndisponivel\r\r\nIP: 138.99.22.42\r\r\nIniciou em: 2018.10.22 as 06:54:50',
#   'ok'),
#  ('Estamos tentando contato com MARIO. Assunto de extrema importancia, CPF: 103-xxx.xxx-48 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('MARA,CNPJ 07113.xxx/xxxx-39,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$109.57 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('FREITAS,CNPJ 15105.xxx/xxxx-49,proposta p/ quitar seu debito referente a CHEQUE ESPECIAL por R$12.03 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('131.221.110.19 DNS-SECUNDARIO', 'ok'),
#  ('!RP,2319,0,1.1.1.1', 'ok'),
#  ('HORUS:DOWN brcgi840 Monitor check-mk-host-ping alarmando DOWN IM_SUPPORT [CRITICAL - 128.129.243.153: Host unreachable @ 128.129.243.138. rt',
#   'ok'),
#  ('SIEM - CMPC \r\r\n[CORE: Outbound cleartext password usage from non guest network detected (Destination IP: 161.69.123.238\r\r\n  Destination Country: United States',
#   'ok'),
#  ('parabens. voce foi selecionado para a etapa presencial na sexta-feira (9h30 ou 14h). envie email para andre-rosa@leadec-services.com e escolha seu horario.',
#   'ok'),
#  ('050003490201|Faça login no aplicativo OlympTrad?: 138.94.167.6, BR, Valparaiso D',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.205.114.94, BR, Itaborai', 'ok'),
#  ('JOAO,CNPJ 02696.xxx/xxxx-78,proposta p/ quitar seu debito referente a CREDITO PESSOAL por R$207.62 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Ei, Ada, seu CPF 024-xxx.xxx-10 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('ADOLFO, proprietario do CPF 036.xxx.xxx-57, seu debito atual junto ao Bradesco e de R$ 4260,94, lance sua proposta! Responda sem custo.',
#   'ok'),
#  ('ANGELICA, proprietario do CPF 105.xxx.xxx-88, seu debito atual junto ao Bradesco e de R$ 13131,25, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('recuperamos seu usuario e senha de acesso no infojobs! usuario: jessicadossantos.224@e-mail.com. senha: jhoncaleb. obrigado!',
#   'ok'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_RoalnetIndisponivel\r\r\nIP: 138.99.22.29\r\r\nIniciou em: 2018.08.15 as 04:33:49',
#   'ok'),
#  ('Login from ip address 138.94.71.54. Confirmation code: 022423', 'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?4PZQP6TT',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 131.161.13.25, BR, Divinopolis', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?QMQ5SI13',
#   'blocked'),
#  ('JOSE,CNPJ 07352.xxx/xxxx-20,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$77.29 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 131.100.63.107, BR, Cianorte', 'ok'),
#  ('050003EA0201|[SDS_BR][Event Occurrence] Warning (arssgpweb01) ( arssgpweb01 ) 105.103.253.117[arssgpweb01] : failed to get the Agent status by AgentInfo.dll. [',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?ZU9ZBBYX',
#   'blocked'),
#  ('Gruppen SIEM - CORE: Outbound cleartext password usage from non guest network detected (Destination IP: 149.7.32.19\r\r\n  Destination Country: United States\r\r\n  Des',
#   'ok'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_BenoitIndisponivel\r\r\nIP: 138.99.23.14\r\r\nIniciou em: 2018.08.11 as 15:51:45',
#   'ok'),
#  ('ADRIANA, CPF 073.xxx.xxx-31, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?9IHEZMCY',
#   'blocked'),
#  ('CICERA, CPF 094.xxx.xxx-23, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Use 66906 para verificar marciano_pazinato@resourceful-bear-99373.com usando Chrome em Windows 10',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 152.237.220.187, BR, Teresina', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?BSP1JP93',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 142.93.112.40, US, North Bergen',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?1KPJLYCY',
#   'blocked'),
#  ('Ei, Andrade, seu CPF 110-xxx.xxx-30 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('Estamos tentando contato com MARIA. Assunto de extrema importancia, CPF: 134-xxx.xxx-15 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('ANA, CPF 103.xxx.xxx-78, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?0PRLAR91',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 143.255.205.180, BR, Itapevi', 'ok'),
#  ('AMAURI, proprietario do CPF 147xxx.xxx-13, seu ibicard c&a visa e de R$ 1519,99, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 128.201.24.179, BR, Maraba', 'ok'),
#  ('ABILIO, proprietario do CPF 031.xxx.xxx-77, seu debito atual junto ao Bradesco e de R$ 48990,95, lance sua proposta! Responda sem custo.',
#   'ok'),
#  ('AVAYA-SBCE-MIB:enterprises.50000.2.0.11 (1.3.6.1.4.1.50000.2.0.11) at 12/13/2018 5:25:54 AM',
#   'ok'),
#  ('Estamos tentando contato com KARINE. Assunto de extrema importancia, CPF: 071-xxx.xxx-09 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('Voce tem uma nova foto http://fotosms.xyz/c/d?i=pv9hrqg6T', 'blocked'),
#  ('PingdomAlert DOWN: BHS 1 - Servidor Ernas (158.69.39.113) is DOWN since 07/01/2019  11:38:16.',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.185.8.6, BR, Riachuelo', 'ok'),
#  ('LUCIANO,CNPJ 11016.xxx/xxxx-72,proposta p/ quitar seu debito referente a CARTAO CREDITO por R$127.73 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('OlympTrad? login: 168.196.44.58, BR, Itapiranga', 'ok'),
#  ("Server 'HD201' is DOWN: ip=158.69.79.112, port=80. Error=Connection timed out",
#   'ok'),
#  ('ALV,CNPJ 08626.xxx/xxxx-90,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$631.1 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Ei, Barbara, seu CPF 090-xxx.xxx-07 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('ANA, proprietario do CPF 154xxx.xxx-20, seu ibicard c&a visa e de R$ 5696,19, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?FJZUU2YC',
#   'blocked'),
#  ('Agnato, Voce tem uma nova foto http://fotosms.xyz/c/d?i=2Ii7tpAaQW',
#   'blocked'),
#  ('Service Manager Number: N-IM028605152 Reported: %BGP/5/BGP_STATE_CHANGED(l): 100.64.3.49 state is changed from ESTABLISHED to IDLE. ;  -1/2',
#   'ok'),
#  ('ROTA,CNPJ 01647.xxx/xxxx-25,proposta p/ quitar seu debito referente a CHEQUE ESPECIAL por R$514.6 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Your iOs ID has been blocked, an unknown device has just logged into iCloud, verify identity: https://apple.com.us-i.bid/?id=200',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 170.231.112.73, BR, Itaborai', 'ok'),
#  ('Ei, Anderson, seu CPF 044-xxx.xxx-44 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('Estamos tentando contato com JOSE. Assunto de extrema importancia, CPF: 068-xxx.xxx-56 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('BRUNO, proprietario do CPF 106.xxx.xxx-60, seu debito atual junto ao Bradesco e de R$ 24215,63, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('ALERT SERVER DISK SPACE   \r\nserver: streaming69  \r\nIP: 144.217.79.12  \r\nDisk: /dev/sdb1 \r\nDisk space used: 85%  \r\nEvent registred in: Fri May 31 2019 11:44:00 GMT-',
#   'ok'),
#  ('Ei, Ana, seu CPF 031-xxx.xxx-18 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('Estamos tentando contato com MARIA. Assunto de extrema importancia, CPF: 114-xxx.xxx-10 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('iCloud alerta; iPhone em modo perdido localizado, acesse, Https://iCloud-buscas.com/iCloud/ para maiores informacoes Apple inc.',
#   'blocked'),
#  ('-- ping (ativo) -- L2_BLUSTELECOM_BGP_JOSI -- as 03:56:34. IP: 131.255.124.206',
#   'ok'),
#  ('050003740403|01.ec2.gru.network\r\n\r\nDetails:\r\nHi DCO,\r\n\r\nWe have received a notification from Cisco as below:\r\n\r\n\r\nNOTIFICATION SENT TO: \r\nNOTIFICATION SENT TIME:. Reply 27986',
#   'ok'),
#  ('OlympTrad? login: 122.248.45.35, ID, Jakarta', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?0LL0P960',
#   'blocked'),
#  ('Bem Vindo ao _UNICRED informa: Seu telefone esta desatualizado. Evite o BLOQUEIO de sua conta. Recadastre agora Acesse http://bit.ly/2E9bDkc',
#   'blocked'),
#  ('presados, sabado nao consta dia de abertura e nem fechamento na same. desativado hoje na senha de ian as 7:05.vanguard',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?90BKHYJM',
#   'blocked'),
#  ('-- ping (inativo) -- LINK_SUL_INT_LINK1_100_200Mb -- as 03:16:14. IP: 167.249.95.242',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 169.57.142.112, BR, Sao Paulo', 'ok'),
#  ('Estamos tentando contato com JUSSARA. Assunto de extrema importancia, CPF: 129-xxx.xxx-06 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('Trisul S/A: Existe debito em aberto junto à Trisul. Favor contatar a Central 11 4130-6000 e Portal do Cliente ou enviar comprovante à carteira@trisul-sa.com.br',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.117.188.25, BR, Igarapava', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 165.227.124.71, US, Clifton', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?4BH5Y3L9',
#   'blocked'),
#  ('S/A,CNPJ 12685.xxx/xxxx-00,proposta p/ quitar seu debito referente a CHEQUE ESPECIAL por R$8.16 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?O93G73FO',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?IGZ6E3PH',
#   'blocked'),
#  ('Estamos tentando contato com SANDRA. Assunto de extrema importancia, CPF: 114-xxx.xxx-14 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('ANA, CPF 107.xxx.xxx-32, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Sub_SP-Guarany2: Status=PROBLEM Detalhe: Ping_Status = Down (0)   Data: 2019.01.27     Hora: 10:13:54       IP: 168.181.136.6',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.227.34.220, BR, Araraquara', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?QMIJBHMA',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?R95LWVLT',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 164.163.236.210, BR, Luiziania', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 165.156.39.53, US, Cincinnati', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.0.99.104, BR, Cotia', 'ok'),
#  ('Estamos tentando contato com ELIZABETH. Assunto de extrema importancia, CPF: 123-xxx.xxx-04 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 160.238.243.38, BR, Buritis', 'ok'),
#  ('CRISTIANE, CPF 059.xxx.xxx-99, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://ve.x-sms-santander.com/?5511985946100',
#   'blocked'),
#  ('050003710201|Faça login no aplicativo OlympTrad?: 138.204.88.191, BR, Itaquaquec',
#   'ok'),
#  ('Ei, Antonio, seu CPF 161-xxx.xxx-04 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('#IP#123456#104.236.205.182#7204#', 'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?J74CTZ1R',
#   'blocked'),
#  ('Apple Informa:\r\nSeu iPhone 8 Plus foi encontrado hoje, as 23:02.\r\nAcesse:\r\nwww.buscar-meu-iphone.com/icloud/ebfbc\r\npara obter a ultima localizacao do dispositivo.',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 128.201.136.4, BR, Manaus', 'ok'),
#  ('http://bit.ly/2nrLnYe', 'blocked'),
#  ('RECURSO INOPERANTE - ITECT-ATRIUM-FWL 138.122.67.6', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.181.51.61, BR, Curitiba', 'ok'),
#  ('Estamos tentando contato com GERSINA. Assunto de extrema importancia, CPF: 139-xxx.xxx-48 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 131.100.243.206, BR, Campos', 'ok'),
#  ('Ei, Andrea, seu CPF 075-xxx.xxx-51 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://Ds.x-sms-santander.com/?5547991153499',
#   'blocked'),
#  ('Zabbix_Alfa: RESOLVIDO: Acc01-LJO_SaoCristovaoTempo de Resposta Alto\r\r\nIP: 138.99.22.58\r\r\nIniciou em: 2019.03.04 as 03:28:24\r\r\nResolvido em: 2019.03.04 as 03:29:24',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 170.239.37.251, BR, Valenca', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 167.249.168.60, BR, Pio Xii', 'ok'),
#  ('Host : NWT Ip: 138.121.136.18 nao esta respondendo ao ping - 2019-07-05 12:55:02',
#   'ok'),
#  ('Host : RB_Bicanga Ip: 170.244.231.14 nao esta respondendo ao ping - 2019-08-02 02:20:20',
#   'ok'),
#  ('Apple Informa:Seu iPhone 8 Plus 256GB Silver em modo perdido foi localizado.acesse: http://icloud-acess.com/appleid/ e recupere seu dispositivo.Apple inc\r\r\n',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?IQIZC489',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?IGSKZ3AP',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 167.250.174.16, BR, Narandiba', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?XB2U0JHH',
#   'blocked'),
#  ('Pai, Voce tem uma nova foto http://fotosms.xyz/c/d?i=5A1tVs580X',
#   'blocked'),
#  ('Sr.(a) ANDRE,CPF 141.xxx.xxx-00, seu debito junto ao BRADESCO desde 12/05/2007 pode ser quitado hoje por R$600. Ligue agora 08006002934 /whatsapp 11997193858',
#   'ok'),
#  ('Estamos tentando contato com EMERSON. Assunto de extrema importancia, CPF: 102-xxx.xxx-32 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('ADEMAR, proprietario do CPF 078.xxx.xxx-06, seu debito atual junto ao Bradesco e de R$ 4178,17, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?MC1A88OZ',
#   'blocked'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?05713YQW',
#   'blocked'),
#  ('050003620201|Faça login no aplicativo OlympTrad?: 131.196.76.120, BR, Sao Joao D',
#   'ok'),
#  ('https://atualizar-cadastro.com/-APP/', 'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 168.194.201.1, BR, Tres Lagoas', 'ok'),
#  ('ANDERSON, proprietario do CPF 130xxx.xxx-89, seu c&a mastercard e de R$ 3449,99, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.99.54.6, BR, Penha', 'ok'),
#  ('AMANDA, proprietario do CPF 145xxx.xxx-29, seu cartao c&a e de R$ 2741,16, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?8K819IPT',
#   'blocked'),
#  ('Produsys Sistemas: Nova Versao 1.3.7.0 Protocolos 075912 075947', 'ok'),
#  ('-: A 123 agora é 123Mob, vá na GooglePlay e baixe  “123mob” nas versões passageiro ou driver. Em breve também a versão IOS. Conheça as novidades em 123mob.com',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?QSPIXT7J',
#   'blocked'),
#  ('VNV,CNPJ 07126.xxx/xxxx-61,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$101.25 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('ANA, propriatario do CPF 164xxx.xxx-45, seu ibicard c&a visa e de R$ 11088,57, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('RENATO, proprietario do CPF 052.xxx.xxx-28, seu debito atual junto ao Bradesco e de R$ 2956, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.219.21.116, BR, Ponte Branca',
#   'ok'),
#  ('PingdomAlert DOWN: BHS 1 - CenterServer (158.69.39.113) is DOWN since 25/12/2018  09:08:30.',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 128.201.223.67, BR, Itatiba', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 131.100.63.53, BR, Paicandu', 'ok'),
#  ('Service Manager Number: N-IM029195799 Reported: %BGP/5/BGP_STATE_CHANGED(l): 100.64.3.41 state is changed from ESTABLISHED to IDLE. ;  -1/2',
#   'ok'),
#  ('Ei, Alexandre, seu CPF 121-xxx.xxx-52 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('Find My iPhone, Your iPhone 7 128GB Black was found today at 10:53 GMT See the last known location here. www.system-icloud.com/?id=3630\r\r\n',
#   'blocked'),
#  ('Estamos tentando contato com MILTON. Assunto de extrema importancia, CPF: 161-xxx.xxx-30 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('050003700403|udsuporteapple.com/IDapple Todos os diretores reservados,\r\n- Suporte',
#   'blocked'),
#  ('#ip,888888,104.236.33.152,7111,1#', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 143.137.77.151, BR, Baia Formosa',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?YCI5MBF7',
#   'blocked'),
#  ('SCAM,CNPJ 06251.xxx/xxxx-79,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$103.8 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.204.27.189, BR, Curitiba', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.122.84.227, BR, São Cristóvão',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 170.0.64.62, BR, Cafelandia', 'ok'),
#  ('Host : NAVEGUE Ip: 138.121.136.118 nao esta respondendo ao ping - 2019-04-19 23:35:05',
#   'ok'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_NexsulIndisponivel\r\r\nIP: 138.99.22.98\r\r\nIniciou em: 2019.02.12 as 21:21:53',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 152.250.183.80, BR, Osasco', 'ok'),
#  ('050003670605|Zscaler Miami node IP (165.225.32.36) and any one Public IP for 300 packets whenever user comes across the problem.Next update will be shared tomorrow o',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 164.163.37.177, BR, Ipatinga', 'ok'),
#  ('Estamos tentando contato com JULIANA. Assunto de extrema importancia, CPF: 053-xxx.xxx-48 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('0500034D0202|? Email tara@slate-ny.com to RSVP', 'ok'),
#  ('Click, Voce tem uma nova foto http://fotosms.xyz/c/d?i=3E6qLppHwc',
#   'blocked'),
#  ('R,CNPJ 09473.xxx/xxxx-19,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$819.05 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.185.56.90, BR, Paulo Afonso',
#   'ok'),
#  ('All Net: popniteroi-mkt-rb2011-2 DOWN CRITICAL - Time to live exceeded (11.11.12.59) Sun Oct 7 14:01:44 BRT 2018',
#   'ok'),
#  ('Ei, Ana, seu CPF 124-xxx.xxx-78 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('Seu iPhone X 64 GB Space Gray foi localizado hoje ?s 05:54 Hrs, ?ltima localiza??o dispon?vel em: https://lcloud-iforgot.com/?id=1252',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?DTKI3H0D',
#   'blocked'),
#  ('Apple Informa:\r\niPhone de Alice foi localizado hoje, as 22:07.\r\nAcesse:\r\nwww.buscar-idevice.com/icloud\r\npara obter a ultima localizacao do dispositivo.',
#   'blocked'),
#  ('All Net: popalmalex-mkt-rb1100ahx2-2 DOWN CRITICAL - Time to live exceeded (11.11.12.58) Wed Dec 5 06:19:00 BRST 2018',
#   'ok'),
#  ('131.221.110.19 DNS-SECUNDARIO', 'ok'),
#  ('Estamos tentando contato com ODAIR. Assunto de extrema importancia, CPF: 160-xxx.xxx-68 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?ADI7ZOOE',
#   'blocked'),
#  ('CAMILA, proprietario do CPF 100.xxx.xxx-50, seu debito atual junto ao Bradesco e de R$ 2632,33, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('-- ping (ativo) -- ASTERISK1 -- as 14:21:27. IP: 131.255.124.3', 'ok'),
#  ('Sr.(a) EDSON,CPF 081.xxx.xxx-38, seu debito junto ao BRADESCO desde 29/02/2012 pode ser quitado hoje por R$2200. Ligue agora 08006002934 /whatsapp 11997193858',
#   'ok'),
#  ('H,CNPJ 15260.xxx/xxxx-83,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$913.16 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('L,CNPJ 03011.xxx/xxxx-85,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$471.34 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?J8GDH34Q',
#   'blocked'),
#  ('MARCELLA, CPF 129.xxx.xxx-99, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.197.140.242, BR, Brasilia', 'ok'),
#  ('Estamos tentando contato com FABIO. Assunto de extrema importancia, CPF: 086-xxx.xxx-11 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('Seu dispositivo 7 Plus Rose foi rastreado e localizado as 19:33h acesse: www.suportedoicloud.com.br/buscar para mais detalhes.',
#   'blocked'),
#  ('FocoMultimídia: ERRO URGENTE - SISTEMA OFFLINE Nome: Api Foco IP: 104.197.207.54',
#   'ok'),
#  ('All Net: popadeus2-mkt-switch DOWN CRITICAL - Time to live exceeded (11.11.12.93) Sun Aug 19 17:34:17 BRT 2018',
#   'ok'),
#  (' Medida de seguranca necessaria a sua conta Apple. \r\nAcesse  imediatamente cliente-icloud.com/ para medidas adicionais e evite o bloqueio.',
#   'blocked'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?KEQTTDUP',
#   'blocked'),
#  ('DIELLY, proprietario do CPF 041.xxx.xxx-50, seu debito atual junto ao Bradesco e de R$ 6298,17, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('OlympTrad? login: 165.156.39.57, US, Cincinnati', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?JJ8JJQ0U',
#   'blocked'),
#  ('Estamos tentando contato com HERNANDES. Assunto de extrema importancia, CPF: 089-xxx.xxx-10 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('Estamos tentando contato com MARCIO. Assunto de extrema importancia, CPF: 002-xxx.xxx-40 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('Estamos tentando contato com MARIA. Assunto de extrema importancia, CPF: 081-xxx.xxx-33 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('050003E00201|Faça login no aplicativo OlympTrad?: 168.205.139.2, BR, Duque De Ca',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?XHV783QT',
#   'blocked'),
#  ('LEONARDO VIVO: Bom dia Bruna, segue e-mail para envio de comprovante leonardo.bueno@c-trends.com.br ',
#   'ok'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_BenoitIndisponivel\r\r\nIP: 138.99.23.14\r\r\nIniciou em: 2018.09.23 as 14:48:45',
#   'ok'),
#  ('Estamos tentando contato com CAMILA. Assunto de extrema importancia, CPF: 069-xxx.xxx-52 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('CAROLINA, proprietario do CPF 125.xxx.xxx-25, seu debito atual junto ao Bradesco e de R$ 3644,39, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('A,CNPJ 07656.xxx/xxxx-92,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$172.15 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('V,CNPJ 04024.xxx/xxxx-09,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$120.34 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.185.216.140, BR, Guarulhos', 'ok'),
#  ('lPhone 8 ha sido encontrado a las 06:17 pm on December 29, 2017 en Barcelona. Ver la ultima ubicacion en https://lcloud.id/LC Soporte-AppIe',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?Y9TQWV4R',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 152.243.157.46, BR, Sao Paulo', 'ok'),
#  ('ARNALDO, CPF 040.xxx.xxx-80, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.204.27.23, BR, Curitiba', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.219.110.199, BR, Ampere', 'ok'),
#  ('GLOBAL,CNPJ 06348.xxx/xxxx-62,proposta p/ quitar seu debito referente a CARTAO CREDITO por R$95.1 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.118.171.167, BR, Campo Largo',
#   'ok'),
#  ('GINA, CPF 148.xxx.xxx-38, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('All Net: popgvt-mkt-allgvt05 DOWN CRITICAL - Time to live exceeded (11.11.12.72) Sun Aug 19 17:33:56 BRT 2018',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?QWV4RB9I',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?OJFR3UKT',
#   'blocked'),
#  ('Estamos tentando contato com ANDRE. Assunto de extrema importancia, CPF: 165-xxx.xxx-42 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('ITALO,CNPJ 04908.xxx/xxxx-88,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$334.2 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://Lz.x-sms-santander.com/?5511986952000',
#   'blocked'),
#  ('Sr.(a) CARLOS,CPF 054.xxx.xxx-93, seu debito junto ao BRADESCO desde 06/05/2013 pode ser quitado hoje por R$1000. Ligue agora 08006002934 /whatsapp 11997193858',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?63FX9B0L',
#   'blocked'),
#  ('131.221.110.19 DNS-SECUNDARIO', 'ok'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://oo.x-sms-santander.com/?5511985455935',
#   'blocked'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?VS34BH5Y',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?MAWDDQ1U',
#   'blocked'),
#  ('BORGES,CNPJ 06041.xxx/xxxx-01,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$371.35 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('idsupport-icloud.com/Find/Apple/', 'blocked'),
#  ('Estamos tentando contato com JOSE. Assunto de extrema importancia, CPF: 051-xxx.xxx-05 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('PingdomAlert UP: LK Hangar (131.108.216.46) is UP again at 12/01/2019  15:34:56. Downtime: 1m.',
#   'ok'),
#  ('-- ping (inativo) -- RB_MELMANN_TELECOM -- as 15:24:16. IP: 167.249.95.234',
#   'ok'),
#  ('All Net: popipanema-mkt-rb1100ahx2-quartier DOWN CRITICAL - Time to live exceeded (11.11.12.13) Sat Sept 22 19:26:11 BRT 2018',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.255.131.114, BR, Cidreira', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?A6TK98OD',
#   'blocked'),
#  ('Zabbix 9010-Botafogo:: BGP Session from MICROSOFT 104.44.13.124, AS 8075 with ACTIVE (3) DOWN\r\r\nbgpSession[MICROSOFT]',
#   'ok'),
#  ('Ei, Reginaldo, seu CPF 035-xxx.xxx-42 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?XQVFFQS0',
#   'blocked'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://WF.x-sms-santander.com/?5511987614580',
#   'blocked'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?S9LM0K3G',
#   'blocked'),
#  ('PROBLEM: FW S.Luis queda de rede 170.238.12.82\r\r\nAlert:High', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 152.250.244.117, BR, Americana', 'ok'),
#  ('Bebo, Voce tem uma nova foto http://fotosms.xyz/c/d?i=2V0cHqbBmK',
#   'blocked'),
#  ('ST500NTW;205778137;03;0;show.claro.com.br;83994086350;claro;192.99.106.15;5050;158.69.137.129;5050;;;',
#   'ok'),
#  ('MARCOS, CPF 022.xxx.xxx-52, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('050003370201|Faça login no aplicativo OlympTrad?: 139.162.180.59, DE, Frankfurt ',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 167.250.184.205, BR, Itaperucu', 'ok'),
#  ('Voce tem uma nova foto http://fotosms.xyz/c/d?i=6kLjDryjbE', 'blocked'),
#  ('PIN: 389972. We have detected that you are login from United States using IP 109.94.220.39, please use this pin to authorize your login!',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.194.160.152, BR, Curitiba', 'ok'),
#  ('ADRIANA, propriatario do CPF 127xxx.xxx-02, seu cartao c&a e de R$ 2109,43, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('N,CNPJ 01471.xxx/xxxx-07,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$1241.92 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?VXG779LJ',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 168.0.99.60, BR, Cotia', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 131.0.217.50, BR, Sao Paulo', 'ok'),
#  ('0500035E0202|mdocs Product Support (APS)\r\r\n\r\r\nRef:MSG1204767\r\r\n Rcvd Frm: Amdocs Customer Support <support@amdocs-support.com>',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 128.199.58.151, NL, Amsterdam', 'ok'),
#  ('COML,CNPJ 01437.xxx/xxxx-90,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$637.1 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.205.79.150, BR, Itanhanga', 'ok'),
#  ('Gruppem SIEM - Outbound cleartext password usage from non guest network detected (Destination IP: 129.73.116.92\r\r\n  Destination TCP/UDP Port: 20\r\r\n (FTP-DATA)) Ve',
#   'ok'),
#  ('0500034C0201|Faça login no aplicativo OlympTrad?: 143.255.216.235, BR, Barra Do ',
#   'ok'),
#  ('0500036B0201|Faça login no aplicativo OlympTrad?: 168.227.101.52, BR, Palmeira D',
#   'ok'),
#  (' Acesso em : 09/08/2019 21:36:10 Conta: grasisantana336@gmail.com IP: 138.94.85.207 Cel: 5513997271404',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?8TC8KRZP',
#   'blocked'),
#  ('Ei, Ademar, seu CPF 052-xxx.xxx-14 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 152.252.45.52, BR, Jundiai', 'ok'),
#  ('ATHAYDE, proprietario do CPF 007.xxx.xxx-91, seu debito atual junto ao Bradesco e de R$ 67135,09, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.204.25.146, BR, Curitiba', 'ok'),
#  ('ALINE, propriatario do CPF 109xxx.xxx-78, seu c&a mastercard e de R$ 5840,64, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://fe.x-sms-santander.com/?5511987258863',
#   'blocked'),
#  ('0500033B0201|Faça login no aplicativo OlympTrad?: 131.108.230.30, BR, Ribeirao D',
#   'ok'),
#  ('ADILSON, propriatario do CPF 123xxx.xxx-40, seu c&a mastercard e de R$ 2421,79, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://KB.x-sms-santander.com/?5511985476312',
#   'blocked'),
#  ('[SulAmerica] Corretor: YAMAHA MOTOR CORR DE SEGS LTDA - backoffice.corretora@yamaha-motor.com.br - (11) 2431-6840 / (11) 98685-1180',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?G66SH0K0',
#   'blocked'),
#  ('Quentinha, Voce tem uma nova foto http://fotosms.xyz/c/d?i=2ZNT5rWbUt',
#   'blocked'),
#  ('Voce tem uma nova foto http://fotosms.xyz/c/d?i=3KPOerFX91', 'blocked'),
#  ('ANA,CNPJ 02821.xxx/xxxx-78,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$322.27 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('0500036F0201|Faça login no aplicativo OlympTrad?: 170.239.215.212, BR, Sao Bento',
#   'ok'),
#  ('SHAPE,CNPJ 06253.xxx/xxxx-10,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$114.73 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('OlympTrad? login: 138.36.20.144, BR, Dom Eliseu', 'ok'),
#  ('CLAUDIO, CPF 025.xxx.xxx-13, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.94.191.48, BR, Icara', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?IT1PFV5P',
#   'blocked'),
#  ('Denis, Voce tem uma nova foto http://fotosms.xyz/c/d?i=4nhxert77k',
#   'blocked'),
#  ('adminip123456 104.198.32.171 4405', 'ok'),
#  ('060804D4C00202|CondomÃ\xadnio 6 Bairro: Recanto Novo CosmÃ³polis IP 100.64.3.82 | COSMONET_FIBRA_Ismael / Senha: 9960??!!',
#   'ok'),
#  ('adminip123456 165.227.66.59 7801', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?1QOJ1G14',
#   'blocked'),
#  ('Ei, Fernando, seu CPF 004-xxx.xxx-20 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 131.221.99.22, BR, Toritama', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.185.184.109, BR, Torres', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.121.98.78, BR, Ubatuba', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?AEQTEO26',
#   'blocked'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://KM.x-sms-santander.com/?5511987464730',
#   'blocked'),
#  ('CENTRO,CNPJ 07142.xxx/xxxx-04,proposta p/ quitar seu debito referente a CARTAO CREDITO por R$3541.18 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('MB TEMPER: Seu pedido de codigo 02606-LOBO.COM, nosso numero 191730, esta pronto! Valor: R$ 216,62, 1,9m2, 38kg. Enviado via WebGlass.',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?02Y2P4XX',
#   'blocked'),
#  ('ERIVALDO, CPF 046.xxx.xxx-20, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
# ...
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?XVIXAOUP',
#   'blocked'),
#  ('TOP_SMS: ID:5953573 - Sev.: 6\r\nDate: 14/12 02:10 - Status: In Progress\r\nSol.: ATBR9SR001PVA -161.89.128.30- DEVICE REBOOTED\r\nRel.CIs: ATBR9SR001PVA',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.59.193.67, BR, Magalhaes', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?ZZUOO3T9',
#   'blocked'),
#  ('Produsys Sistemas: Nova Versao 1.0.2.3 Protocolos 075286 075339', 'ok'),
#  ('-- ping (ativo) -- LINK_SUL_INT_LINK2_500Mb -- as 20:21:22. IP: 167.249.95.245',
#   'ok'),
#  ('OlympTrad? login: 116.0.54.30, PK, Lahore', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.219.236.105, BR, Sao Leopoldo',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?6M0ACT2T',
#   'blocked'),
#  ('OlympTrad? login: 110.74.196.138, KH, ', 'ok'),
#  ('ALERTA  HOST:SWITCH HUAWEI 6720 CONSORCIO - EUNAPOLIS , 100.64.0.33, Sun Dec 16 00:00:42 BRST 2018 , STATUS:DOWN        ',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.99.54.10, BR, Penha', 'ok'),
#  ('050003720201|Faça login no aplicativo OlympTrad?: 128.201.219.38, BR, Sao Goncal',
#   'ok'),
#  ('MAGI,CNPJ 05148.xxx/xxxx-09,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$14.1 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('OlympTrad? login: 103.219.212.157, IN, Jaipur', 'ok'),
#  ('Estamos tentando contato com ANDREIA. Assunto de extrema importancia, CPF: 059-xxx.xxx-30 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('Ei, Daiane, seu CPF 147-xxx.xxx-09 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('BRUNA,CNPJ 00899.xxx/xxxx-02,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$1150.98 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 126.60.59.36, JP, Gifu', 'ok'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_Teutonet (AS267301)Indisponivel\r\r\nIP: 138.99.22.15\r\r\nIniciou em: 2019.02.06 as 11:01:47',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.204.142.249, BR, Itacare', 'ok'),
#  ('Sr.(a) SONIA,CPF 154.xxx.xxx-04, seu debito junto ao BRADESCO desde 10/09/2012 pode ser quitado hoje por R$1000. Ligue agora 08006002934 /whatsapp 11997193858',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.0.20.227, BR, Juazeiro', 'ok'),
#  ('OlympTrad? login: 132.255.37.229, BR, Morungaba', 'ok'),
#  ('BBinforma: voce possui 90 mil pontos Smiles Gol expirando hoje, vinculados em seu Ourocard, resgate agora acessando: http://bbsmiles.sytes.net',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?CMSK2UTU',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?V9RTTJY0',
#   'blocked'),
#  ('PROBLEM: FW S.Luis queda de rede 170.238.12.82\r\r\nAlert:High', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 170.239.0.22, BR, Fortaleza', 'ok'),
#  ('recuperamos seu usuario e senha de acesso no infojobs! usuario: carlos.castro@axa-assistance.com.br. senha: obiuankanob. obrigado!',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?4AAR3J8V',
#   'blocked'),
#  ('-- ping (ativo) -- VSC1 -- as 17:40:50. IP: 131.255.124.96', 'ok'),
#  ('050003230201|Faça login no aplicativo OlympTrad?: 138.204.88.190, BR, Itaquaquec',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?4574CLDL',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 162.251.61.127, US, Chicago', 'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?G4JQKWZJ',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 168.181.146.75, BR, Cariacica', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.197.76.251, BR, Caxias Do Sul',
#   'ok'),
#  ('ADILSON, proprietario do CPF 104.xxx.xxx-52, seu debito atual junto ao Bradesco e de R$ 7296,19, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('TRIGO,CNPJ 06991.xxx/xxxx-27,proposta p/ quitar seu debito referente a CAPITAL GIRO por R$103.37 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('050003780201|Faça login no aplicativo OlympTrad?: 170.233.78.250, BR, Francisco ',
#   'ok'),
#  ('050003070201|Faça login no aplicativo OlympTrad?: 168.228.214.54, BR, Sao Joao D',
#   'ok'),
#  ('Ei, Adriano, seu CPF 017-xxx.xxx-09 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('ANA, proprietario do CPF 124.xxx.xxx-20, seu debito atual junto ao Bradesco e de R$ 2528,56, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('Ei, Adriana, seu CPF 141-xxx.xxx-90 pode sair de restricao em ate 5 dias. Ligue hoje e garanta a melhor negociacao em carater de excecao 08002759600.',
#   'ok'),
#  ('06080447D20202|Novo Cosmopolis | IP: 100.64.3.31 GTW: 100.64.3.1 REDE: COSMONET_FIBRA_lhrp SENHA: 103457brc',
#   'ok'),
#  ('-- ping (ativo) -- LINK_SUL_INT_LINK2_500Mb -- as 15:38:53. IP: 167.249.95.245',
#   'ok'),
#  ("Server 'HD202' is DOWN: ip=158.69.93.94, port=80. Error=Connection timed out",
#   'ok'),
#  ('0500037C0201|Faça login no aplicativo OlympTrad?: 168.227.12.40, BR, Itaquaquece',
#   'ok'),
#  ('Prezado(a) Leandro o modo perdido do seu iPhone 6 foi ativado com sucesso, acesse: https://isupport-apple.com/icloud/ para obter a localizacao atual. AppIeCare.',
#   'blocked'),
#  ('050003230201|Faça login no aplicativo OlympTrad?: 143.208.196.78, BR, Sao Bento ',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.36.196.43, BR, Campos', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.117.178.38, BR, Ilheus', 'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?2XQCXQCA',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 168.196.64.242, BR, Rondonopolis',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?213J79T1',
#   'blocked'),
#  ('Suporte Informa: Dispositivo 5S 16GB Silver foi localizado pelo iCloud as 17:46 Acesse https://apple-iplace.com/buscar/ para visualizar a localizacao.',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?DFAJTF6L',
#   'blocked'),
#  ('Gruppen SIEM - Outbound cleartext password usage from non guest network detected (Destination IP: 152.195.213.131\r\r\n  Destination TCP/UDP Port: 11\r\r\n (SYSTAT)) Ve',
#   'ok'),
#  ('Zabbix_Alfa: PROBLEMA: Acc01-LJO_SaoCristovaoIndisponivel\r\r\nIP: 138.99.22.58\r\r\nIniciou em: 2018.10.10 as 21:23:18',
#   'ok'),
#  ('ALERTA FREE: Prezado Cliente, Evite o reajuste de sua anuidade para 109,90 em seu cartao, realizando o cancelamento gratuito no Canal: is.gd/AnuidadeFREE',
#   'blocked'),
#  ('bitnuvem.com: Identificamos acesso do IP 170.239.47.2 na sua conta. 28/08 13:46',
#   'ok'),
#  ('B.B INFORMA: Prezado(a) cliente, Atualizacao para seu Mobile, acesse o link e siga as obstrucoes https://atualizarmobile.co',
#   'blocked'),
#  ('ABDIAS, proprietario do CPF 024.xxx.xxx-34, seu debito atual junto ao Bradesco e de R$ 5616,83, lance sua proposta! Responda sem custo.',
#   'ok'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_BRNetIndisponivel\r\r\nIP: 138.99.22.42\r\r\nIniciou em: 2018.11.13 as 01:57:50',
#   'ok'),
#  ('Aaa, Voce tem uma nova foto http://fotosms.xyz/c/d?i=60UONqpK1O',
#   'blocked'),
#  ('ELIANE, CPF 113.xxx.xxx-58, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('Gra, Voce tem uma nova foto http://fotosms.xyz/c/d?i=51hkPq8HRU',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 131.108.87.8, BR, Barreiros', 'ok'),
#  ('Partio Website is Down from 12 13 AM BRT . Down reason , Host Unavailable . Down from location Rio de Janeiro - BR(186.226.57.44),Sao Paulo - BR(148.163.220.12',
#   'ok'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_BRNetIndisponivel\r\r\nIP: 138.99.22.42\r\r\nIniciou em: 2019.01.07 as 14:53:50',
#   'ok'),
#  ('CELSO, proprietario do CPF 115.xxx.xxx-97, seu debito atual junto ao Bradesco e de R$ 12546,7, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 152.250.93.166, BR, Sao Paulo', 'ok'),
#  ('Zabbix_Alfa: PROBLEMA: ISP_BenoitIndisponivel\r\r\nIP: 138.99.23.14\r\r\nIniciou em: 2019.02.12 as 21:22:45',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.99.132.162, BR, Sao Goncalo',
#   'ok'),
#  ('DELAIRA, CPF 045.xxx.xxx-25, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('ANDRE, CPF 056.xxx.xxx-62, uma condicao excepcional foi aprovada p/ quitar seu debito junto ao BRADESCO. Ligue agora 08006002934/ wpp 11997193858',
#   'ok'),
#  ('0500032E0201|Faça login no aplicativo OlympTrad?: 170.244.204.48, BR, Feira De S',
#   'ok'),
#  ('Caio, Voce tem uma nova foto http://fotosms.xyz/c/d?i=16yRxrtCkj',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?QEBEDUO6',
#   'blocked'),
#  ('LUIZ, proprietario do CPF 047.xxx.xxx-46, seu debito atual junto ao Bradesco e de R$ 589,08, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.122.84.152, BR, São Cristóvão',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 146.236.200.8, US, Chicago', 'ok'),
#  ('OlympTrad? login: 106.111.53.26, CN, ', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 167.250.226.142, BR, Campo Maior',
#   'ok'),
#  ('BB INFORMA: SUA SENHA J EXPIROU ACESSE E VALIDE AGORA: www.Bbrasildesbloqueio.com/?VX9UCQ85',
#   'blocked'),
#  ('-- ping (ativo) -- LINK_SUL_TELECOM_BKP -- as 01:21:21. IP: 167.249.95.246',
#   'ok'),
#  ("Voce tem 11 nota(s) distribuidas do(a) JE/RS em 03/09/2018 no e-mail 'padilhae@via-rs.net'.",
#   'ok'),
#  ('Luis, Voce tem uma nova foto http://fotosms.xyz/c/d?i=k8rur9Wgb',
#   'blocked'),
#  ('050003510201|Faça login no aplicativo OlympTrad?: 138.255.200.42, BR, Canaa Dos ',
#   'ok'),
#  ('ANA, proprietario do CPF 051.xxx.xxx-03, seu debito atual junto ao Bradesco e de R$ 3666,25, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.0.153.164, BR, Pentecoste', 'ok'),
#  ('050003940202|id5.vmall.com/iforgot  para reiniciar sua senha.', 'blocked'),
#  ('ALVARO, proprietario do CPF 066.xxx.xxx-96, seu debito atual junto ao Bradesco e de R$ 17356,68, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 152.238.115.40, BR, Juiz De Fora',
#   'ok'),
#  ('All Net: popmexico21-mkt-ccr1016-fibra DOWN CRITICAL - Time to live exceeded (11.11.12.124) Sat Sept 29 10:38:55 BRT 2018',
#   'ok'),
#  ('Estamos tentando contato com JANAINA. Assunto de extrema importancia, CPF: 057-xxx.xxx-93 . Entre em contato pelo telefone: 08007213569 ou Whats: (11)976509508',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 152.250.159.143, BR, Sao Paulo', 'ok'),
#  ('OlympTrad? login: 103.5.187.234, IN, Mumbai', 'ok'),
#  ('Zabbix_Alfa: RESOLVIDO: VMware08-VM_DNS2-LJOIndisponivel\r\r\nIP: 138.99.22.67\r\r\nIniciou em: 2019.02.12 as 21:27:17\r\r\nResolvido em: 2019.02.12 as 21:27:47',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?XK3JCP15',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 138.204.25.74, BR, Curitiba', 'ok'),
#  ('CASSIA, propriatario do CPF 126xxx.xxx-86, seu ibicard c&a visa e de R$ 3914,07, lance sua proposta! Ligue gratis 08006002628',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 152.237.225.174, BR, Teresina', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 128.201.156.205, BR, Abreu E Lima',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 138.219.182.114, BR, Jacobina', 'ok'),
#  ('TOP_SMS: ID:6000602 - Sev.: 6\r\nDate: 25/01 01:57 - Status: New\r\nSol.: ATBR9TS009PVA -161.89.129.104- POSSIBLE OS FREEZE\r\nRel.CIs: ATBR9TS009PVA',
#   'ok'),
#  ('FRANCISCO, proprietario do CPF 135.xxx.xxx-87, seu debito atual junto ao Bradesco e de R$ 16828,68, lance sua proposta! WhatsApp 11955831425',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 131.221.171.235, BR, Salvador', 'ok'),
#  ('Sra Tatiana,segue email para mandar solicitacao de cancelamento \r\nassinada atendimento@eccosalva-rs.com.br',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?W0GV71ZD',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 138.94.85.226, BR, Itanhaem', 'ok'),
#  ('Host : Servidor Netflix Ip: 138.121.139.230 nao esta respondendo ao ping - 2019-04-19 19:55:04',
#   'ok'),
#  ('Sr.(a) MARIA,CPF 092.xxx.xxx-97, seu debito junto ao BRADESCO desde 10/11/2010 pode ser quitado hoje por R$1300. Ligue agora 08006002934 /whatsapp 11997193858',
#   'ok'),
#  ('Deeiri, Voce tem uma nova foto http://fotosms.xyz/c/d?i=1sfnRqJax4',
#   'blocked'),
#  ('OlympTrad? login: 109.167.134.253, RU, Saint Petersburg', 'ok'),
#  ('Sent from your Twilio trial account - Payleven informa sua conta foi bloqueada para desbloquear sua conta acesso o link https://brasilprepagos.herokuapp.com/',
#   'blocked'),
#  ('Gruppen SIEM - Outbound cleartext password usage from non guest network detected (Destination IP: 100.126.1.190\r\r\n  Destination TCP/UDP Port: 11\r\r\n (SYSTAT)) Veri',
#   'ok'),
#  ('? Find my iPhone : Nova localizacao iPhone modo perdido,acesse   https://appleidrastreio.com/icloud/ veja a ultima localizacao.  Apple Inc',
#   'blocked'),
#  ('Subestacao Morro Sul-Guarany2: Status=PROBLEM Detalhe: Ping_Status = Down (0)   Data: 2019.03.04     Hora: 19:52:54       IP: 168.181.136.6',
#   'ok'),
#  ('Produsys Sistemas: Nova Versao 1.0.8.4 Protocolo 074487', 'ok'),
#  ('Faça login no aplicativo OlympTrad?: 167.250.31.166, BR, Porto Alegre',
#   'ok'),
#  ('OlympTrad? login: 143.0.91.247, BR, Taquaritinga', 'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?MC1XJG6P',
#   'blocked'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?Z1GBVFWD',
#   'blocked'),
#  ('060804E6C60201|[SDS_BR][Event Occurrence] Event Level:Warning (System Name:BRTSSDB02) (Object Label:BRTSSDB02) Event Title:105.103.5.124[BRTSSDB02] : failed to g',
#   'ok'),
#  ('Le Grand Klabin: chegou uma encomenda na portaria. Remetente: mercado livre  pt  165.212.735.br Destinatario: Mônica',
#   'ok'),
#  ('Sr.(a) BASSEM,CPF 002.xxx.xxx-68, seu debito junto ao BRADESCO desde 10/09/2013 pode ser quitado hoje por R$3200. Ligue agora 08006002934 /whatsapp 11997193858',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?H8H0AG5X',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 170.231.113.82, BR, Sao Goncalo',
#   'ok'),
#  ('Faça login no aplicativo OlympTrad?: 168.227.77.105, BR, Buriti Alegre',
#   'ok'),
#  ('Holanda, Voce tem uma nova foto http://fotosms.xyz/c/d?i=2botfpWuQs',
#   'blocked'),
#  ('Faça login no aplicativo OlympTrad?: 152.242.104.86, BR, Jaboatao', 'ok'),
#  ("Server 'HD202' is DOWN: ip=158.69.93.94, port=80. Error=Connection timed out",
#   'ok'),
#  ('SMF,CNPJ 03131.xxx/xxxx-38,proposta p/ quitar seu debito referente a RENEGOCIACAO DE DIVIDA por R$123.22 valida ate 08/03. Ligue 08006002934 /whats 11997193858',
#   'ok'),
#  ('BB INFORMA:VALIDE SUA SENHA E EVITE TRANSTORNO. ACESSE: www.Bbrasildesbloqueio.com/?PFGFW6V1',
#   'blocked'),
#  ('050003790201|Faça login no aplicativo OlympTrad?: 170.233.78.227, BR, Francisco ',
#   'ok'),
#  ('Estamos tentando contato com VANESSA. Assunto de extrema importancia, CPF: 015-xxx.xxx-18 . Entre em contato pelo telefone: 1127393055 ou Whats: (11)976509508',
#   'ok'),
#  ('Banco Santander.\r\r\n\r\r\nPrezado(a) Cliente evite o bloqueio de seu cartao e senhas. Refaca a Operacao. Acesse: http://ta.x-sms-santander.com/?5511985476012',
#   'blocked'),
#  ('Fornecedor, Consta no SICAF, o CNPJ(101.187.178.55) está vencido. Para renovar, Acesse : www.e-sicafweb.com.br ou (011) 2122-0202',
#   'ok'),
#  ...]

# %%
base_final = estruturar_dados(base_treino)

# %%
base_final[0]
# Out:
# ({'faç': True,
#   'login': True,
#   'aplic': True,
#   'olymptrad': True,
#   '13172109159': True,
#   'br': True,
#   'embuguacu': True,
#   'grupp': False,
#   'si': False,
#   'outbound': False,
#   'cleartext': False,
#   'password': False,
#   'usag': False,
#   'from': False,
#   'non': False,
#   'guest': False,
#   'network': False,
#   'detected': False,
#   'destination': False,
#   'ip': False,
#   '1044418195': False,
#   'tcpudp': False,
#   'port': False,
#   '11': False,
#   'systat': False,
#   'ver': False,
#   'marc': False,
#   'cpf': False,
#   '097xxxxxx04': False,
#   'condica': False,
#   'excepc': False,
#   'aprov': False,
#   'p': False,
#   'quit': False,
#   'debit': False,
#   'junt': False,
#   'brad': False,
#   'lig': False,
#   'agor': False,
#   '08006002934': False,
#   'wpp': False,
#   '11997193858': False,
#   'sra': False,
#   'karlacpf': False,
#   '116xxxxxx76': False,
#   'desd': False,
#   '15092006': False,
#   'pod': False,
#   'ser': False,
#   'hoj': False,
#   'r600': False,
#   'whatsapp': False,
#   'bb': False,
#   'informavalid': False,
#   'senh': False,
#   'evit': False,
#   'transtorn': False,
#   'acess': False,
#   'wwwbbrasildesbloqueiocomgfqke15': False,
#   'bitnuvemcom': False,
#   'identific': False,
#   '1382042545': False,
#   'cont': False,
#   'nao': False,
#   'conhec': False,
#   'atualiz': False,
#   'imediat': False,
#   'israel': False,
#   'voc': False,
#   'nov': False,
#   'fot': False,
#   'httpfotosmsxyzcdi6e3nepqxp4': False,
#   'tent': False,
#   'contat': False,
#   'ana': False,
#   'assunt': False,
#   'extrem': False,
#   'importanc': False,
#   '032xxxxxx19': False,
#   'telefon': False,
#   '1127393055': False,
#   'what': False,
#   '11976509508': False,
#   'banc': False,
#   'santand': False,
#   'prezado': False,
#   'client': False,
#   'bloquei': False,
#   'carta': False,
#   'refac': False,
#   'operaca': False,
#   'httpbcxsmssantandercom5511985866210': False,
#   'centrocnpj': False,
#   '05977xxxxxxx62propost': False,
#   'refer': False,
#   'capit': False,
#   'gir': False,
#   'r8662': False,
#   'val': False,
#   'ate': False,
#   '0803': False,
#   '050003780201f': False,
#   '138204235118': False,
#   'cab': False,
#   's': False,
#   '131021714': False,
#   'sao': False,
#   'paul': False,
#   'wwwbbrasildesbloqueiocomav46qrzk': False,
#   'joanacnpj': False,
#   '02587xxxxxxx44propost': False,
#   'renegociaca': False,
#   'div': False,
#   'r8292': False,
#   'elian': False,
#   'propriatari': False,
#   '142xxxxxx09': False,
#   'ca': False,
#   'mastercard': False,
#   'r': False,
#   '272021': False,
#   'lanc': False,
#   'propost': False,
#   'gratil': False,
#   '08006002628': False,
#   'abc': False,
#   'is': False,
#   'down': False,
#   '1': False,
#   '25': False,
#   'pm': False,
#   'brst': False,
#   'reason': False,
#   'read': False,
#   'tim': False,
#   'out': False,
#   'location': False,
#   'br14816322012miam': False,
#   'us1992018955ri': False,
#   'jan': False,
#   'br18': False,
#   'abraa': False,
#   '116xxxxxx63': False,
#   '389672': False,
#   'respond': False,
#   'cust': False,
#   'jeffersoncnpj': False,
#   '01571xxxxxxx58propost': False,
#   'r12384': False,
#   'httpbrxsmssantandercom5511986853151': False,
#   '1032052678': False,
#   'kh': False,
#   'phnom': False,
#   'penh': False,
#   'serv': False,
#   'ping': False,
#   'disposi': False,
#   'estaca': False,
#   'glor': False,
#   'dalp': False,
#   'ap': False,
#   'basebox': False,
#   '1001001614': False,
#   'pass': False,
#   'statu': False,
#   'ip1001001614': False,
#   'sistem': False,
#   'horari': False,
#   'comerc': False,
#   'sip': False,
#   '17023112129': False,
#   'hor': False,
#   '21042019': False,
#   '165121': False,
#   'corre': False,
#   '0500033a0201f': False,
#   '14325553207': False,
#   'raimun': False,
#   '131031140': False,
#   'maca': False,
#   '170244152130': False,
#   'fri': False,
#   'wwwbbrasildesbloqueiocomakadlrxb': False,
#   'wwwbbrasildesbloqueiocomutfdl28': False,
#   'ei': False,
#   'francisc': False,
#   '003xxxxxx10': False,
#   'sair': False,
#   'restrica': False,
#   '5': False,
#   'dia': False,
#   'garant': False,
#   'melhor': False,
#   'negociaca': False,
#   'carat': False,
#   'exceca': False,
#   '08002759600': False,
#   'inform': False,
#   '24hr': False,
#   'httpsgooglwqekgq': False,
#   'dad': False,
#   'wwwbbrasildesbloqueiocompqa925z': False,
#   'fornec': False,
#   'const': False,
#   'sicaf': False,
#   'cnpj10118717855': False,
#   'venc': False,
#   'renov': False,
#   'wwwesicafwebcombr': False,
#   '011': False,
#   '21220202': False,
#   'leonard': False,
#   'viv': False,
#   'bom': False,
#   'marcel': False,
#   'seg': False,
#   'email': False,
#   'leonardobuenoctrendscombr': False,
#   'grat': False,
#   'j': False,
#   'expir': False,
#   'valid': False,
#   'wwwbbrasildesbloqueiocomu361i5my': False,
#   '041xxxxxx10': False,
#   '0500030b0201f': False,
#   '13894176251': False,
#   'agu': False,
#   'lind': False,
#   '118173233149': False,
#   'th': False,
#   'bang': False,
#   'khen': False,
#   'codevasf': False,
#   'codig': False,
#   'otwt': False,
#   'validad': False,
#   '23042019': False,
#   '1741': False,
#   'orig': False,
#   '13802339': False,
#   '351996254': False,
#   'servmarnew': False,
#   'public': False,
#   '152243101236': False,
#   'adautocpf': False,
#   '036xxxxxx92': False,
#   '08112011': False,
#   'r1200': False,
#   '168205501': False,
#   'barr': False,
#   'bugr': False,
#   'anderson': False,
#   '018xxxxxx67': False,
#   'hernand': False,
#   '089xxxxxx10': False,
#   'wwwbbrasildesbloqueiocom0y3w7hf6': False,
#   'wwwbbrasildesbloqueiocom5e4hd9p': False,
#   'wwwbbrasildesbloqueiocomowb1le3h': False,
#   '0500032e0201f': False,
#   '170150226149': False,
#   'ferraz': False,
#   '130xxxxxx94': False,
#   'wald': False,
#   '124xxxxxx34': False,
#   '08007213569': False,
#   '170233123154': False,
#   'natal': False,
#   '050003120201f': False,
#   '138117167142': False,
#   'estrel': False,
#   'd': False,
#   'scnpj': False,
#   '03509xxxxxxx20propost': False,
#   'r21852': False,
#   '1265411588': False,
#   'jp': False,
#   'gifu': False,
#   '168197155104': False,
#   'capita': False,
#   'poc': False,
#   'gruppen': False,
#   '15225514051': False,
#   'alert': False,
#   'freeresolv': False,
#   'onelin': False,
#   'canalhttpritaboloscombrspryassetsfreern': False,
#   '13116138148': False,
#   'poxor': False,
#   'wwwbbrasildesbloqueiocomrz3s5y30': False,
#   'adilson': False,
#   '077xxxxxx26': False,
#   'alessandr': False,
#   'proprietari': False,
#   '126xxxxxx02': False,
#   'atual': False,
#   '579529': False,
#   '11955831425': False,
#   'susi': False,
#   '015xxxxxx84': False,
#   'charl': False,
#   '032xxxxxx28': False,
#   'ativ': False,
#   'asterisk1': False,
#   '161726': False,
#   '1312551243': False,
#   'ccnpj': False,
#   '01319xxxxxxx41propost': False,
#   'r20525': False,
#   'adri': False,
#   '051xxxxxx07': False,
#   'cattan': False,
#   'atenca': False,
#   'acord': False,
#   'amanh': False,
#   'efetu': False,
#   'pagamentoduvidascontat': False,
#   'malt': False,
#   '08006048080s': False,
#   'pag': False,
#   'desconsid': False,
#   'zoomnethost': False,
#   'backbon': False,
#   'oitil': False,
#   '131255342': False,
#   '20190224': False,
#   '125201': False,
#   'empreiteiracnpj': False,
#   '00593xxxxxxx54propost': False,
#   'r9503': False,
#   'celil': False,
#   'httpfotosmsxyzcdi5ha2ps8jhx': False,
#   'solic': False,
#   'autorizaã§ã£': False,
#   'msaudememorialsaudecombr': False,
#   '170233148141': False,
#   'marab': False,
#   'wilmaaa': False,
#   'httpfotosmsxyzcdi1gzusr8dc8': False,
#   '1641633233': False,
#   'trindad': False,
#   'ip12345616522766597099': False,
#   '1311612272': False,
#   'fortal': False,
#   'wwwbbrasildesbloqueiocomuj0yhed': False,
#   'support': False,
#   'appl': False,
#   'requi': False,
#   'verifiqu': False,
#   'su': False,
#   'id': False,
#   'visit': False,
#   'el': False,
#   'sigui': False,
#   'enlac': False,
#   'detall': False,
#   'httpicloudfindsupportcomhntw9sg': False,
#   'httpqexsmssantandercom5511986169096': False,
#   'httpauxsmssantandercom5511987825219': False,
#   'zabbixalf': False,
#   'problem': False,
#   'ispnagel': False,
#   'netindisponi': False,
#   '138992246': False,
#   'inici': False,
#   '20190206': False,
#   '110233': False,
#   'wwwbbrasildesbloqueiocomwotoa0bz': False,
#   'wwwbbrasildesbloqueiocome8jqhj57': False,
#   '050003460201f': False,
#   '13820411334': False,
#   '152255132148': False,
#   've': False,
#   'all': False,
#   'net': False,
#   'poplevel3mktrb1016ccr': False,
#   'critic': False,
#   'to': False,
#   'liv': False,
#   'exceeded': False,
#   '11111266': False,
#   '182252': False,
#   '2019': False,
#   'wwwbbrasildesbloqueiocomzgzz1844': False,
#   'host': False,
#   'nwt': False,
#   '13812113618': False,
#   'volt': False,
#   '20190729': False,
#   '224002': False,
#   '15225514045': False,
#   '105555': False,
#   'wwwbbrasildesbloqueiocomboqwzgkp': False,
#   '1381862712': False,
#   '0608': False,
#   '1639': False,
#   'ada': False,
#   '023xxxxxx01': False,
#   'allan': False,
#   '093xxxxxx93': False,
#   'pingdomalert': False,
#   'ovh': False,
#   'bazelgeus': False,
#   'ern': False,
#   '14244178175': False,
#   'sinc': False,
#   '23082019': False,
#   '003516': False,
#   'ispbrnetindisponi': False,
#   '138992242': False,
#   '20181022': False,
#   '065450': False,
#   'mari': False,
#   '103xxxxxx48': False,
#   'maracnpj': False,
#   '07113xxxxxxx39propost': False,
#   'r10957': False,
#   'freitascnpj': False,
#   '15105xxxxxxx49propost': False,
#   'chequ': False,
#   'espec': False,
#   'r1203': False,
#   '13122111019': False,
#   'dnssecundari': False,
#   'rp231901111': False,
#   'horusdown': False,
#   'brcgi840': False,
#   'moni': False,
#   'checkmkhostping': False,
#   'alarm': False,
#   'imsupport': False,
#   '128129243153': False,
#   'unreachabl': False,
#   '128129243138': False,
#   'rt': False,
#   'cmpc': False,
#   'cor': False,
#   '16169123238': False,
#   'country': False,
#   'united': False,
#   'stat': False,
#   'parab': False,
#   'selecion': False,
#   'etap': False,
#   'presenc': False,
#   'sextaf': False,
#   '9h30': False,
#   '14h': False,
#   'envi': False,
#   'andrerosaleadecservicescom': False,
#   'escolh': False,
#   '050003490201f': False,
#   '138941676': False,
#   'valparais': False,
#   '16820511494': False,
#   'itabor': False,
#   'joaocnpj': False,
#   '02696xxxxxxx78propost': False,
#   'credit': False,
#   'pessoal': False,
#   'r20762': False,
#   '024xxxxxx10': False,
#   'adolf': False,
#   '036xxxxxx57': False,
#   '426094': False,
#   'angel': False,
#   '105xxxxxx88': False,
#   '1313125': False,
#   'recuper': False,
#   'usuari': False,
#   'infojob': False,
#   'jessicadossantos224emailcom': False,
#   'jhoncaleb': False,
#   'obrig': False,
#   'isproalnetindisponi': False,
#   '138992229': False,
#   '20180815': False,
#   '043349': False,
#   'addres': False,
#   '138947154': False,
#   'confirmation': False,
#   'cod': False,
#   '022423': False,
#   'wwwbbrasildesbloqueiocom4pzqp6tt': False,
#   '1311611325': False,
#   'divinopolil': False,
#   'wwwbbrasildesbloqueiocomqmq5si13': False,
#   'josecnpj': False,
#   '07352xxxxxxx20propost': False,
#   'r7729': False,
#   '13110063107': False,
#   'cianort': False,
#   '050003ea0201sdsbrevent': False,
#   'occurrenc': False,
#   'warning': False,
#   'arssgpweb01': False,
#   '105103253117arssgpweb01': False,
#   'failed': False,
#   'get': False,
#   'the': False,
#   'agent': False,
#   'by': False,
#   'agentinfodll': False,
#   'wwwbbrasildesbloqueiocomzu9zbbyx': False,
#   '14973219': False,
#   'de': False,
#   'ispbenoitindisponi': False,
#   '138992314': False,
#   '20180811': False,
#   '155145': False,
#   '073xxxxxx31': False,
#   'wwwbbrasildesbloqueiocom9ihezmcy': False,
#   'cic': False,
#   '094xxxxxx23': False,
#   'use': False,
#   '66906': False,
#   'verific': False,
#   'marcianopazinatoresourcefulbear99373com': False,
#   'us': False,
#   'chrom': False,
#   'window': False,
#   '10': False,
#   '152237220187': False,
#   'teresin': False,
#   'wwwbbrasildesbloqueiocombsp1jp93': False,
#   '1429311240': False,
#   'north': False,
#   'bergen': False,
#   'wwwbbrasildesbloqueiocom1kpjlycy': False,
#   'andrad': False,
#   '110xxxxxx30': False,
#   'mar': False,
#   '134xxxxxx15': False,
#   '103xxxxxx78': False,
#   'wwwbbrasildesbloqueiocom0prlar91': False,
#   '143255205180': False,
#   'itapev': False,
#   'amaur': False,
#   '147xxxxxx13': False,
#   'ibicard': False,
#   'vis': False,
#   '151999': False,
#   '12820124179': False,
#   'abili': False,
#   '031xxxxxx77': False,
#   '4899095': False,
#   'avayasbcemibenterprises500002011': False,
#   '136141500002011': False,
#   'at': False,
#   '12132018': False,
#   '52554': False,
#   'am': False,
#   'karin': False,
#   '071xxxxxx09': False,
#   'httpfotosmsxyzcdipv9hrqg6t': False,
#   'bh': False,
#   '1586939113': False,
#   '07012019': False,
#   '113816': False,
#   '13818586': False,
#   'riachuel': False,
#   'lucianocnpj': False,
#   '11016xxxxxxx72propost': False,
#   'r12773': False,
#   '1681964458': False,
#   'itapirang': False,
#   'hd201': False,
#   'ip1586979112': False,
#   'port80': False,
#   'errorconnection': False,
#   'timed': False,
#   'alvcnpj': False,
#   '08626xxxxxxx90propost': False,
#   'r6311': False,
#   'barb': False,
#   '090xxxxxx07': False,
#   '154xxxxxx20': False,
#   '569619': False,
#   'wwwbbrasildesbloqueiocomfjzuu2yc': False,
#   'agnat': False,
#   'httpfotosmsxyzcdi2ii7tpaaqw': False,
#   'manag': False,
#   'numb': False,
#   'nim028605152': False,
#   'reported': False,
#   'bgp5bgpstatechangedl': False,
#   '10064349': False,
#   'changed': False,
#   'established': False,
#   'idl': False,
#   '12': False,
#   'rotacnpj': False,
#   '01647xxxxxxx25propost': False,
#   'r5146': False,
#   'your': False,
#   'io': False,
#   'ha': False,
#   'been': False,
#   'blocked': False,
#   'an': False,
#   'unknown': False,
#   'devic': False,
#   'just': False,
#   'logged': False,
#   'int': False,
#   'icloud': False,
#   'verify': False,
#   'identity': False,
#   'httpsapplecomusibidid200': False,
#   '17023111273': False,
#   '044xxxxxx44': False,
#   'jos': False,
#   '068xxxxxx56': False,
#   'brun': False,
#   '106xxxxxx60': False,
#   '2421563': False,
#   'disk': False,
#   'spac': False,
#   'streaming69': False,
#   '1442177912': False,
#   'devsdb1': False,
#   'used': False,
#   '85': False,
#   'event': False,
#   'registred': False,
#   'in': False,
#   'may': False,
#   '31': False,
#   '114400': False,
#   'gmt': False,
#   '031xxxxxx18': False,
#   '114xxxxxx10': False,
#   'iphon': False,
#   'mod': False,
#   'perd': False,
#   'local': False,
#   'httpsicloudbuscascomicloud': False,
#   'mai': False,
#   'informaco': False,
#   'inc': False,
#   'l2blustelecombgpjos': False,
#   '035634': False,
#   '131255124206': False,
#   '05000374040301ec2grunetwork': False,
#   'detail': False,
#   'hi': False,
#   'dco': False,
#   'we': False,
#   'hav': False,
#   'received': False,
#   'notification': False,
#   'cisc': False,
#   'below': False,
#   'sent': False,
#   'reply': False,
#   '27986': False,
#   '1222484535': False,
#   'jakart': False,
#   'wwwbbrasildesbloqueiocom0ll0p960': False,
#   'bem': False,
#   'vind': False,
#   'unicred': False,
#   'desatu': False,
#   'recadastr': False,
#   'httpbitly2e9bdkc': False,
#   'pres': False,
#   'sab': False,
#   'abert': False,
#   'fech': False,
#   'sam': False,
#   'desativ': False,
#   'ian': False,
#   '705vanguard': False,
#   'wwwbbrasildesbloqueiocom90bkhyjm': False,
#   'inat': False,
#   'linksulintlink1100200mb': False,
#   '031614': False,
#   '16724995242': False,
#   '16957142112': False,
#   'juss': False,
#   '129xxxxxx06': False,
#   'trisul': False,
#   'sa': False,
#   'exist': False,
#   'favor': False,
#   'centr': False,
#   '41306000': False,
#   'comprov': False,
#   'carteiratrisulsacombr': False,
#   '13811718825': False,
#   'igarap': False,
#   '16522712471': False,
#   'clifton': False,
#   'wwwbbrasildesbloqueiocom4bh5y3l9': False,
#   'sacnpj': False,
#   '12685xxxxxxx00propost': False,
#   'r816': False,
#   'wwwbbrasildesbloqueiocomo93g73f': False,
#   'wwwbbrasildesbloqueiocomigz6e3ph': False,
#   'sandr': False,
#   '114xxxxxx14': False,
#   '107xxxxxx32': False,
#   'subspguarany2': False,
#   'statusprobl': False,
#   'detalh': False,
#   'pingstatu': False,
#   '0': False,
#   'dat': False,
#   '20190127': False,
#   '101354': False,
#   '1681811366': False,
#   '16822734220': False,
#   'araraqu': False,
#   'wwwbbrasildesbloqueiocomqmijbhm': False,
#   'wwwbbrasildesbloqueiocomr95lwvlt': False,
#   '164163236210': False,
#   'luizian': False,
#   '1651563953': False,
#   'cincinnat': False,
#   '168099104': False,
#   'cot': False,
#   'elizabeth': False,
#   '123xxxxxx04': False,
#   '16023824338': False,
#   'buritil': False,
#   'cristian': False,
#   '059xxxxxx99': False,
#   'httpvexsmssantandercom5511985946100': False,
#   '050003710201f': False,
#   '13820488191': False,
#   'itaquaquec': False,
#   'antoni': False,
#   '161xxxxxx04': False,
#   'ip1234561042362051827204': False,
#   'wwwbbrasildesbloqueiocomj74ctz1r': False,
#   '8': False,
#   'plu': False,
#   'encontr': False,
#   '2302': False,
#   'wwwbuscarmeuiphonecomicloudebfbc': False,
#   'obt': False,
#   'ult': False,
#   'localizaca': False,
#   '1282011364': False,
#   'manau': False,
#   'httpbitly2nrlny': False,
#   'recurs': False,
#   'inoper': False,
#   'itectatriumfwl': False,
#   '138122676': False,
#   '1681815161': False,
#   'curitib': False,
#   'gersin': False,
#   '139xxxxxx48': False,
#   '131100243206': False,
#   'camp': False,
#   'andre': False,
#   '075xxxxxx51': False,
#   'httpdsxsmssantandercom5547991153499': False,
#   'resolv': False,
#   'acc01ljosaocristovaotemp': False,
#   'respost': False,
#   'alt': False,
#   '138992258': False,
#   '20190304': False,
#   '032824': False,
#   '032924': False,
#   '17023937251': False,
#   'valenc': False,
#   '16724916860': False,
#   'pio': False,
#   'xii': False,
#   '20190705': False,
#   '125502': False,
#   'rbbicang': False,
#   '17024423114': False,
#   '20190802': False,
#   '022020': False,
#   'informas': False,
#   '256gb': False,
#   'silv': False,
#   'localizadoac': False,
#   'httpicloudacesscomappleid': False,
#   'recup': False,
#   'dispositivoappl': False,
#   'wwwbbrasildesbloqueiocomiqizc489': False,
#   'wwwbbrasildesbloqueiocomigskz3ap': False,
#   '16725017416': False,
#   'narandib': False,
#   'wwwbbrasildesbloqueiocomxb2u0jhh': False,
#   'pai': False,
#   'httpfotosmsxyzcdi5a1tvs580x': False,
#   'andrecpf': False,
#   '141xxxxxx00': False,
#   '12052007': False,
#   'emerson': False,
#   '102xxxxxx32': False,
#   'adem': False,
#   '078xxxxxx06': False,
#   '417817': False,
#   'wwwbbrasildesbloqueiocommc1a88oz': False,
#   'wwwbbrasildesbloqueiocom05713yqw': False,
#   '050003620201f': False,
#   '13119676120': False,
#   'joa': False,
#   'httpsatualizarcadastrocomapp': False,
#   '1681942011': False,
#   'tre': False,
#   'lago': False,
#   '130xxxxxx89': False,
#   '344999': False,
#   '13899546': False,
#   'amand': False,
#   '145xxxxxx29': False,
#   '274116': False,
#   'wwwbbrasildesbloqueiocom8k819ipt': False,
#   'produsy': False,
#   'versa': False,
#   '1370': False,
#   'protocol': False,
#   '075912': False,
#   '075947': False,
#   '123': False,
#   '123mob': False,
#   'vá': False,
#   'googleplay': False,
#   'baix': False,
#   '“123mob”': False,
#   'vers': False,
#   'passag': False,
#   'driv': False,
#   'brev': False,
#   'conheç': False,
#   'novidad': False,
#   '123mobcom': False,
#   'wwwbbrasildesbloqueiocomqspixt7j': False,
#   'vnvcnpj': False,
#   '07126xxxxxxx61propost': False,
#   'r10125': False,
#   '164xxxxxx45': False,
#   '1108857': False,
#   'renat': False,
#   '052xxxxxx28': False,
#   '2956': False,
#   '13821921116': False,
#   'pont': False,
#   'branc': False,
#   'centerserv': False,
#   '25122018': False,
#   '090830': False,
#   '12820122367': False,
#   'itatib': False,
#   '1311006353': False,
#   'paicandu': False,
#   'nim029195799': False,
#   '10064341': False,
#   'alexandr': False,
#   '121xxxxxx52': False,
#   'find': False,
#   'my': False,
#   '7': False,
#   '128gb': False,
#   'black': False,
#   'wa': False,
#   'found': False,
#   'today': False,
#   '1053': False,
#   'see': False,
#   'last': False,
#   'known': False,
#   'her': False,
#   'wwwsystemicloudcomid3630': False,
#   'milton': False,
#   '161xxxxxx30': False,
#   '050003700403udsuporteapplecomidappl': False,
#   'tod': False,
#   'dire': False,
#   'reserv': False,
#   'suport': False,
#   'ip8888881042363315271111': False,
#   '14313777151': False,
#   'bai': False,
#   'form': False,
#   'wwwbbrasildesbloqueiocomyci5mbf7': False,
#   'scamcnpj': False,
#   '06251xxxxxxx79propost': False,
#   'r1038': False,
#   '13820427189': False,
#   '13812284227': False,
#   'cristóv': False,
#   '17006462': False,
#   'cafeland': False,
#   'naveg': False,
#   '138121136118': False,
#   '20190419': False,
#   '233505': False,
#   'ispnexsulindisponi': False,
#   '138992298': False,
#   '20190212': False,
#   '212153': False,
#   '15225018380': False,
#   'osasc': False,
#   '050003670605zscal': False,
#   'miam': False,
#   'nod': False,
#   '1652253236': False,
#   'and': False,
#   'any': False,
#   'one': False,
#   '300': False,
#   'packet': False,
#   'whenev': False,
#   'com': False,
#   'acros': False,
#   'problemnext': False,
#   'updat': False,
#   'will': False,
#   'be': False,
#   'shared': False,
#   'tomorrow': False,
#   '16416337177': False,
#   'ipating': False,
#   'juli': False,
#   '053xxxxxx48': False,
#   '0500034d0202': False,
#   'taraslatenycom': False,
#   'rsvp': False,
#   'click': False,
#   'httpfotosmsxyzcdi3e6qlpphwc': False,
#   'rcnpj': False,
#   '09473xxxxxxx19propost': False,
#   'r81905': False,
#   '1381855690': False,
#   'afons': False,
#   'popniteroimktrb20112': False,
#   '11111259': False,
#   'sun': False,
#   'oct': False,
#   '140144': False,
#   'brt': False,
#   '2018': False,
#   '124xxxxxx78': False,
#   'x': False,
#   '64': False,
#   'gb': False,
#   'gray': False,
#   '0554': False,
#   'hr': False,
#   'ltim': False,
#   'localiza': False,
#   'dispon': False,
#   'httpslcloudiforgotcomid1252': False,
#   'wwwbbrasildesbloqueiocomdtki3h0d': False,
#   'alic': False,
#   '2207': False,
#   'wwwbuscaridevicecomicloud': False,
#   'popalmalexmktrb1100ahx22': False,
#   '11111258': False,
#   'wed': False,
#   'dec': False,
#   '061900': False,
#   'oda': False,
#   '160xxxxxx68': False,
#   'wwwbbrasildesbloqueiocomadi7zoo': False,
#   'camil': False,
#   '100xxxxxx50': False,
#   '263233': False,
#   '142127': False,
#   'edsoncpf': False,
#   '081xxxxxx38': False,
#   '29022012': False,
#   'r2200': False,
#   'hcnpj': False,
#   '15260xxxxxxx83propost': False,
#   'r91316': False,
#   'lcnpj': False,
#   '03011xxxxxxx85propost': False,
#   'r47134': False,
#   'wwwbbrasildesbloqueiocomj8gdh34q': False,
#   'marcell': False,
#   '129xxxxxx99': False,
#   '168197140242': False,
#   'brasil': False,
#   'fabi': False,
#   '086xxxxxx11': False,
#   'ros': False,
#   'rastre': False,
#   '1933h': False,
#   'wwwsuportedoicloudcombrbusc': False,
#   'focomultimíd': False,
#   'err': False,
#   'urgent': False,
#   'offlin': False,
#   'nom': False,
#   'api': False,
#   'foc': False,
#   '10419720754': False,
#   'popadeus2mktswitch': False,
#   '11111293': False,
#   'aug': False,
#   '19': False,
#   ...},
#  'ok')

# %%
# %%time
# Cria o classificador (tabela de probabilidade) com base no conjunto de treinamento
classificador = nltk.NaiveBayesClassifier.train(base_final)
# Out:
# Wall time: 54 s

# %%
# Retorna as classes da base de dados (ok, blocked)
print(classificador.labels())
# Out:
# ['ok', 'blocked']

# %%
# Retorna os 10 atributos mais significativos
print(classificador.show_most_informative_features(10))
# Out:
# Most Informative Features
#                       bb = True           blocke : ok     =   1432.8 : 1.0
#                       br = True               ok : blocke =    247.7 : 1.0
#                        j = True           blocke : ok     =    218.4 : 1.0
#                    debit = True               ok : blocke =    165.1 : 1.0
#                  prezado = True           blocke : ok     =    157.2 : 1.0
#                    aplic = True               ok : blocke =    146.1 : 1.0
#                    local = True           blocke : ok     =    132.8 : 1.0
#                    login = True               ok : blocke =    122.5 : 1.0
#                      lig = True               ok : blocke =    110.9 : 1.0
#                     banc = True           blocke : ok     =     80.9 : 1.0
# None

# %% [markdown]
# ### 3.2.Testando o classificador

# %% [markdown]
# Para testar o classificador, iremos utilizar uma frase para verificar a classificação realizada, uma vez que a base de dados já foi pré-processada e treinada com a base de dados para treino.
#
# Para que a nova frase seja classificada temos que realizar toda a fase de pré-processamento. Como criamos a função ```estruturar_dados```, podemos simplesmente utilizá-la.

# %%
base_teste[0]
# Out:
# ('Sr.(a) JAIRO,CPF 018.xxx.xxx-83, seu debito junto ao BRADESCO desde 25/11/2012 pode ser quitado hoje por R$1600. Ligue agora 08006002934 /whatsapp 11997193858',
#  'ok')

# %%
frase_teste = estruturar_dados([base_teste[0]])
print(frase_teste)
# Out:
# [({'sra': True, 'jairocpf': True, '018xxxxxx83': True, 'debit': True, 'junt': True, 'brad': True, 'desd': True, '25112012': True, 'pod': True, 'ser': True, 'quit': True, 'hoj': True, 'r1600': True, 'lig': True, 'agor': True, '08006002934': True, 'whatsapp': True, '11997193858': True}, 'ok')]

# %%
print(frase_teste[0][0])
caracteristica_teste = frase_teste[0][0]
# Out:
# {'sra': True, 'jairocpf': True, '018xxxxxx83': True, 'debit': True, 'junt': True, 'brad': True, 'desd': True, '25112012': True, 'pod': True, 'ser': True, 'quit': True, 'hoj': True, 'r1600': True, 'lig': True, 'agor': True, '08006002934': True, 'whatsapp': True, '11997193858': True}

# %%
# Realizar a classificação
print(classificador.classify(caracteristica_teste))
# Out:
# ok

# %% [markdown]
# Quando chamamos o método ```classificador.classify``` com o parâmetro ```frase_teste```, o algoritmo classifica a frase como rótulo ```ok```.

# %% [markdown]
# Para visualizar a distribuição de probabilidade utiliza-se o método ```prob_classify``` que mostra a porcentagem para cada uma das classes.

# %%
# Retorna a classe e o valor da distribuição de probabilidade
distribuicao = classificador.prob_classify(caracteristica_teste)

# Para cada classe, verifica-se a probabilidade
for classe in distribuicao.samples():
    print('%s: %f' % (classe, distribuicao.prob(classe)))
# Out:
# ok: 1.000000
# blocked: 0.000000

# %% [markdown]
# # 4.Teste do algoritmo Naive Bayes

# %% [markdown]
# Na etapa de teste, utiliza-se outro conjunto de dados, com o objetivo de testar o algoritmo de aprendizado de máquina com novas frases. Para tal, a base de dados deve conter frases diferentes da base de treinamento e sem a informação de sua classificação (ok, blocked).
#
# O algoritmo é executado novamente e o método ```classify.accuracy```  mostra a proximidade entre o percentual obtido experimentalmente e o valor verdadeiro da classificação das frases.
#
# Passamos como parâmetro o classificador, que nada mais é do que uma tabela de probabilidade que o Naive Bayes gera, e a base de dados para teste.

# %%
frases_teste = estruturar_dados(base_teste)

# %%
print(frases_teste[0])
# Out:
# ({'sra': True, 'jairocpf': True, '018xxxxxx83': True, 'debit': True, 'junt': True, 'brad': True, 'desd': True, '25112012': True, 'pod': True, 'ser': True, 'quit': True, 'hoj': True, 'r1600': True, 'lig': True, 'agor': True, '08006002934': True, 'whatsapp': True, '11997193858': True, 'banc': False, 'santand': False, 'prezado': False, 'client': False, 'evit': False, 'bloquei': False, 'carta': False, 'senh': False, 'refac': False, 'operaca': False, 'acess': False, 'httpluxsmssantandercom5511981870490': False, 'faç': False, 'login': False, 'aplic': False, 'olymptrad': False, '170233180207': False, 'br': False, 'turv': False, 'bb': False, 'informavalid': False, 'transtorn': False, 'wwwbbrasildesbloqueiocomz0my2dd8': False, 'inform': False, 'j': False, 'expir': False, 'valid': False, 'wwwbbrasildesbloqueiocomus16p1gq': False, 'wwwbbrasildesbloqueiocomlgqrka95': False, 'sent': False, 'from': False, 'your': False, 'twili': False, 'trial': False, 'account': False, 'entr': False, 'cont': False, '138022286': False, 'wwwbbrasildesbloqueiocomr14re01y': False, 'all': False, 'net': False, 'popcampograndemktrb20112': False, 'down': False, 'critic': False, 'tim': False, 'to': False, 'liv': False, 'exceeded': False, '11111260': False, 'sun': False, 'aug': False, '19': False, '173430': False, 'brt': False, '2018': False, 'qfcnpj': False, '03948xxxxxxx95propost': False, 'p': False, 'refer': False, 'renegociaca': False, 'div': False, 'r170203': False, 'val': False, 'ate': False, '0803': False, 'what': False, '13122113125': False, 'pass': False, 'fund': False, 'wwwbbrasildesbloqueiocom5z43drij': False, '050003740201f': False, '13897110149': False, 'conceica': False, '050003240201f': False, '13110016686': False, 'ribeira': False, 'wwwbbrasildesbloqueiocomi4ihibfp': False, 'golden': False, 'joa': False, 'parcel': False, 'venc': False, 'disponibiliz': False, 'segund': False, 'via': False, 'bolet': False, 'email': False, 'joaoritterviarsnet': False, '125209116234': False, 'pk': False, 'karach': False, 'successful': False, '10162018': False, '71049': False, 'pm': False, '1312559051': False, '1322551803': False, 'luzian': False, 'edson': False, 'cpf': False, '006xxxxxx96': False, 'condica': False, 'excepc': False, 'aprov': False, 'wpp': False, 'distribuidoracnpj': False, '00616xxxxxxx90propost': False, 'capit': False, 'gir': False, 'r19187': False, 'ip123456104236321417205': False, 'horusdown': False, 'pontoeletronicosp1': False, 'moni': False, 'checkmkhostping': False, 'alarm': False, 'imsupport': False, '12812928242': False, 'rta': False, 'nan': False, 'lost': False, '100': False, 'ei': False, 'aryton': False, '122xxxxxx49': False, 'sair': False, 'restrica': False, '5': False, 'dia': False, 'garant': False, 'melhor': False, 'negociaca': False, 'carat': False, 'exceca': False, '08002759600': False, 'rcnpj': False, '05958xxxxxxx60propost': False, 'r3949': False, '050003640202aslatenycom': False, 'rsvp': False, '15225022948': False, 'piracicab': False, 'wwwbbrasildesbloqueiocomquii029': False, '10357143246': False, 'in': False, 'mumb': False, '109245229229': False, 'rs': False, 'beljevac': False, 'ping': False, 'ativ': False, 'linksulintlink1100200mb': False, '010204': False, 'ip': False, '16724995242': False, 'voc': False, 'nov': False, 'fot': False, 'httpfotosmsxyzcdi6h6usqy96m': False, 'tent': False, 'contat': False, 'abdovald': False, 'assunt': False, 'extrem': False, 'importanc': False, '094xxxxxx02': False, 'telefon': False, '1127393055': False, '11976509508': False, 'wwwbbrasildesbloqueiocomufyl9i0c': False, 'wwwbbrasildesbloqueiocomb2byymg': False, 'wwwbbrasildesbloqueiocom9jqpogp4': False, '14325596164': False, 'ararangu': False, '1682057037': False, 'sao': False, 'vicent': False, 'oopscnpj': False, '07066xxxxxxx27propost': False, 'r10882': False, 'ubiraj': False, '125xxxxxx85': False, 'wwwbbrasildesbloqueiocomhgbyk5ad': False, 'wwwbbrasildesbloqueiocomfbshbyzv': False, '168227111195': False, 'goian': False, 'unicred': False, 'numer': False, 'des ...

# %% [markdown]
# O método ```classify.accuracy``` funciona da seguinte forma: ele submete todos os registros da base de teste ao classificador e o classificador gera uma classificação para cada um dos registros. Após isso, realiza uma comparação entre a classificação gerada e a classifcação que já tinha sido realizada na base de dados, e devolve a taxa de acerto.

# %%
acurácia = nltk.classify.accuracy(classificador, frases_teste)
acurácia_percentual = acurácia*100

print("A acurácia da classificação da base teste é de {:.4}%".format(acurácia_percentual))
# Out:
# A acurácia da classificação da base teste é de 98.42%

# %%
res = {'ok' : 0, 'blocked' : 0}
total = 0
for (texto, classe) in base_teste:
    if classe == 'ok':
        res[classe] += 1
    elif classe == 'blocked':
        res[classe] += 1
    total += 1
print(res)
# Out:
# {'ok': 887, 'blocked': 313}

# %%
887 / (887 + 313)
# Out:
# 0.7391666666666666

# %% [markdown]
# Esse resultado possibilita realizar algumas análises, tais como:
#
# 1. **Análise de cenário**: O percentual de acerto do algoritmo é bom ou ruim? R: É muito bom! Corre o risco de overfitting.
# 2. **Análise do número de classes**: A probabilidade mínima aceitável para o algoritmo ser melhor do que usar a aleatoriedade é que a acurácia seja maior que 50%, ou seja, dividir 100% pela quantidade de classes.
# 3. **ZeroRules**: Nessa análise, estamos comparando o resultado obtido pelo sistema, com o método de classificar uma frase de acordo com a classe que possui maior quantidade de frases na base de dados de treino e teste. Por exemplo, dividimos a classe com maior número de registros pelo total de registros na base de dados (```887/1200 = 73,92%```). Desta forma, conclui-se que o sistema apresenta mais acertos do que classificar todas as novas frases nessa classe.

# %% [markdown]
# ## 5.Visualização de erros do algoritmo

# %% [markdown]
# É possível visualizar a classe já pré-classificada, a classe que o algoritmo classificou e a frase vinculada ao erro gerado.
#
# Por exemplo: ```ok blocked {'sra': False,'jairocpf': False,'018xxxxxx83': False,'debit': False,'junt': False, ... ,'sent': True,'from': True,'your': True,'twili': True,...}```. Essa saída nos diz qual a classe correta, ou seja, aquela que está na base de dados para teste é ```ok```. O algoritmo classificou como ```blocked``` e a frase vinculada à classificação possui os radicais ```sent``` e ```from```.
#
# Para identificar corretamente os acertos e erros podemos:

# %%
erros =[]
for (frase, classe) in frases_teste:
    resultado = classificador.classify(frase)
    
    if resultado != classe:
        erros.append((classe, resultado, frase))

# %%
erros[0]
# Out:
# ('ok',
#  'blocked',
#  {'sra': False,
#   'jairocpf': False,
#   '018xxxxxx83': False,
#   'debit': False,
#   'junt': False,
#   'brad': False,
#   'desd': False,
#   '25112012': False,
#   'pod': False,
#   'ser': False,
#   'quit': False,
#   'hoj': False,
#   'r1600': False,
#   'lig': False,
#   'agor': False,
#   '08006002934': False,
#   'whatsapp': False,
#   '11997193858': False,
#   'banc': False,
#   'santand': False,
#   'prezado': False,
#   'client': False,
#   'evit': False,
#   'bloquei': False,
#   'carta': False,
#   'senh': False,
#   'refac': False,
#   'operaca': False,
#   'acess': False,
#   'httpluxsmssantandercom5511981870490': False,
#   'faç': False,
#   'login': False,
#   'aplic': False,
#   'olymptrad': False,
#   '170233180207': False,
#   'br': False,
#   'turv': False,
#   'bb': False,
#   'informavalid': False,
#   'transtorn': False,
#   'wwwbbrasildesbloqueiocomz0my2dd8': False,
#   'inform': False,
#   'j': False,
#   'expir': False,
#   'valid': False,
#   'wwwbbrasildesbloqueiocomus16p1gq': False,
#   'wwwbbrasildesbloqueiocomlgqrka95': False,
#   'sent': True,
#   'from': True,
#   'your': True,
#   'twili': True,
#   'trial': True,
#   'account': True,
#   'entr': True,
#   'cont': True,
#   '138022286': True,
#   'wwwbbrasildesbloqueiocomr14re01y': False,
#   'all': False,
#   'net': False,
#   'popcampograndemktrb20112': False,
#   'down': False,
#   'critic': False,
#   'tim': False,
#   'to': False,
#   'liv': False,
#   'exceeded': False,
#   '11111260': False,
#   'sun': False,
#   'aug': False,
#   '19': False,
#   '173430': False,
#   'brt': False,
#   '2018': False,
#   'qfcnpj': False,
#   '03948xxxxxxx95propost': False,
#   'p': False,
#   'refer': False,
#   'renegociaca': False,
#   'div': False,
#   'r170203': False,
#   'val': False,
#   'ate': False,
#   '0803': False,
#   'what': False,
#   '13122113125': False,
#   'pass': False,
#   'fund': False,
#   'wwwbbrasildesbloqueiocom5z43drij': False,
#   '050003740201f': False,
#   '13897110149': False,
#   'conceica': False,
#   '050003240201f': False,
#   '13110016686': False,
#   'ribeira': False,
#   'wwwbbrasildesbloqueiocomi4ihibfp': False,
#   'golden': False,
#   'joa': False,
#   'parcel': False,
#   'venc': False,
#   'disponibiliz': False,
#   'segund': False,
#   'via': False,
#   'bolet': False,
#   'email': False,
#   'joaoritterviarsnet': False,
#   '125209116234': False,
#   'pk': False,
#   'karach': False,
#   'successful': False,
#   '10162018': False,
#   '71049': False,
#   'pm': False,
#   '1312559051': False,
#   '1322551803': False,
#   'luzian': False,
#   'edson': False,
#   'cpf': False,
#   '006xxxxxx96': False,
#   'condica': False,
#   'excepc': False,
#   'aprov': False,
#   'wpp': False,
#   'distribuidoracnpj': False,
#   '00616xxxxxxx90propost': False,
#   'capit': False,
#   'gir': False,
#   'r19187': False,
#   'ip123456104236321417205': False,
#   'horusdown': False,
#   'pontoeletronicosp1': False,
#   'moni': False,
#   'checkmkhostping': False,
#   'alarm': False,
#   'imsupport': False,
#   '12812928242': False,
#   'rta': False,
#   'nan': False,
#   'lost': False,
#   '100': False,
#   'ei': False,
#   'aryton': False,
#   '122xxxxxx49': False,
#   'sair': False,
#   'restrica': False,
#   '5': False,
#   'dia': False,
#   'garant': False,
#   'melhor': False,
#   'negociaca': False,
#   'carat': False,
#   'exceca': False,
#   '08002759600': False,
#   'rcnpj': False,
#   '05958xxxxxxx60propost': False,
#   'r3949': False,
#   '050003640202aslatenycom': False,
#   'rsvp': False,
#   '15225022948': False,
#   'piracicab': False,
#   'wwwbbrasildesbloqueiocomquii029': False,
#   '10357143246': False,
#   'in': False,
#   'mumb': False,
#   '109245229229': False,
#   'rs': False,
#   'beljevac': False,
#   'ping': False,
#   'ativ': False,
#   'linksulintlink1100200mb': False,
#   '010204': False,
#   'ip': False,
#   '16724995242': False,
#   'voc': False,
#   'nov': False,
#   'fot': False,
#   'httpfotosmsxyzcdi6h6usqy96m': False,
#   'tent': False,
#   'contat': False,
#   'abdovald': False,
#   'assunt': False,
#   'extrem': False,
#   'importanc': False,
#   '094xxxxxx02': False,
#   'telefon': False,
#   '1127393055': False,
#   '11976509508': False,
#   'wwwbbrasildesbloqueiocomufyl9i0c': False,
#   'wwwbbrasildesbloqueiocomb2byymg': False,
#   'wwwbbrasildesbloqueiocom9jqpogp4': False,
#   '14325596164': False,
#   'ararangu': False,
#   '1682057037': False,
#   'sao': False,
#   'vicent': False,
#   'oopscnpj': False,
#   '07066xxxxxxx27propost': False,
#   'r10882': False,
#   'ubiraj': False,
#   '125xxxxxx85': False,
#   'wwwbbrasildesbloqueiocomhgbyk5ad': False,
#   'wwwbbrasildesbloqueiocomfbshbyzv': False,
#   '168227111195': False,
#   'goian': False,
#   'unicred': False,
#   'numer': False,
#   'desatu': False,
#   'recadastr': False,
#   'httpsgooglpxjfyc': False,
#   'carl': False,
#   'proprietari': False,
#   '167xxxxxx69': False,
#   'atual': False,
#   'r': False,
#   '361414': False,
#   'lanc': False,
#   'propost': False,
#   '11955831425': False,
#   'divanilson': False,
#   '067xxxxxx00': False,
#   '61479': False,
#   'wwwbbrasildesbloqueiocomgdx7lzlm': False,
#   'appl': False,
#   'inc': False,
#   'su': False,
#   'iphon': False,
#   '6s': False,
#   'plu': False,
#   'perd': False,
#   'ha': False,
#   'sid': False,
#   'conect': False,
#   'internet': False,
#   'local': False,
#   'bloqu': False,
#   'disposi': False,
#   'visit': False,
#   'httplcloudcocomho6rtnx': False,
#   '050003710201f': False,
#   '13859121196': False,
#   'rio': False,
#   'nai': False,
#   '095xxxxxx40': False,
#   '537416': False,
#   'restrico': False,
#   'httpbitly2n8pts': False,
#   'wwwbbrasildesbloqueiocomc2hm38dy': False,
#   'wwwbbrasildesbloqueiocom1yryg0tw': False,
#   'josuecnpj': False,
#   '05437xxxxxxx60propost': False,
#   'r10881': False,
#   '123mob': False,
#   '123': False,
#   'googleplay': False,
#   'baix': False,
#   'passag': False,
#   'brev': False,
#   'io': False,
#   'novidad': False,
#   '123mobcombr': False,
#   'isabel': False,
#   '093xxxxxx77': False,
#   'mskcnpj': False,
#   '02944xxxxxxx73propost': False,
#   'r16555': False,
#   '131726934': False,
#   'japaratub': False,
#   'anacnpj': False,
#   '04454xxxxxxx12propost': False,
#   'r146043': False,
#   'marsh': False,
#   'corre': False,
#   'suzan': False,
#   'parc': False,
#   '01': False,
#   'seg': False,
#   'aut': False,
#   '16012019': False,
#   'envi': False,
#   'suzanadomusavaliacoescom': False,
#   'esclarec': False,
#   'im': False,
#   'alessandr': False,
#   'propriatari': False,
#   '121xxxxxx77': False,
#   'ca': False,
#   '195497': False,
#   'gratil': False,
#   '08006002628': False,
#   '1389485155': False,
#   'itanha': False,
#   'unicredatendimentobrnet': False,
#   'luil': False,
#   '088xxxxxx33': False,
#   'pingnetbrun': False,
#   '105657': False,
#   '1672499510': False,
#   'rout': False,
#   'prov': False,
#   '132255248174': False,
#   'sep': False,
#   '26': False,
#   '1230': False,
#   'gmt': False,
#   '300': False,
#   '20min': False,
#   '138093136': False,
#   'hamburg': False,
#   '152250195202': False,
#   'paul': False,
#   '10424815483': False,
#   'sg': False,
#   'singapor': False,
#   'httpkaxsmssantandercom5511985469983': False,
#   '13859194203': False,
#   'magalha': False,
#   '13821923130': False,
#   'torixor': False,
#   'vazcnpj': False,
#   '07783xxxxxxx12propost': False,
#   'r10737': False,
#   'grupp': False,
#   'si': False,
#   'outbound': False,
#   'cleartext': False,
#   'password': False,
#   'usag': False,
#   'non': False,
#   'guest': False,
#   'network': False,
#   'detected': False,
#   'destination': False,
#   '1001201690': False,
#   'tcpudp': False,
#   'port': False,
#   '11': False,
#   'systat': False,
#   'ver': False,
#   'suport': False,
#   'icioud': False,
#   'emanuel': False,
#   'iocal': False,
#   '1559': False,
#   'httpswwwbuscarmeuiphonecomid2b814': False,
#   'obt': False,
#   'ult': False,
#   'localizaca': False,
#   '1034225572': False,
#   'id': False,
#   'gorontal': False,
#   'aliriocpf': False,
#   '019xxxxxx68': False,
#   '28012013': False,
#   'lilian': False,
#   '007xxxxxx90': False,
#   '08007213569': False,
#   'wwwbbrasildesbloqueiocom7f043sg': False,
#   'wwwbbrasildesbloqueiocomz539kuil': False,
#   'wwwbbrasildesbloqueiocom9dwi1dh7': False,
#   'jos': False,
#   '094xxxxxx90': False,
#   '138375': False,
#   'aparelh': False,
#   'onlin': False,
#   '1modoperdidocomrastr': False,
#   'vej': False,
#   'map': False,
#   'httpimxsmssantandercom5511986693411': False,
#   'cristian': False,
#   '135xxxxxx25': False,
#   'mastercard': False,
#   '377763': False,
#   '050003eb0201f': False,
#   '16724919184': False,
#   'vitor': False,
#   'test': False,
#   'httpsgooglhc29vk': False,
#   'marcelocpf': False,
#   '106xxxxxx40': False,
#   '26062013': False,
#   'r1900': False,
#   'wwwbbrasildesbloqueiocomfy7jri1': False,
#   'wwwbbrasildesbloqueiocom2xtqq22': False,
#   'avis': False,
#   'ness': False,
#   'carnav': False,
#   'bbsmil': False,
#   'viaj': False,
#   'acessebancodobrasilappsytesnet': False,
#   '149284184': False,
#   'us': False,
#   'piscataway': False,
#   'wwwbbrasildesbloqueiocom75vre7rj': False,
#   'zabbixalf': False,
#   'problem': False,
#   'acc01ljosaocristovaoindisponi': False,
#   '138992258': False,
#   'inici': False,
#   '20180815': False,
#   '043418': False,
#   '8': False,
#   '1723': False,
#   'wwwbuscarmeuiphonecomid024a3': False,
#   'hyund': False,
#   'persi': False,
#   'bom': False,
#   'atend': False,
#   'atendimentohyundaibrasilcom': False,
#   'obrig': False,
#   'psa': False,
#   'par': False,
#   'zabbix': False,
#   'gwsp02': False,
#   'bgp': False,
#   'session': False,
#   'lanautilu': False,
#   '149318198': False,
#   '6762': False,
#   'with': False,
#   'idl': False,
#   '1': False,
#   'bgpsessionlanautilu': False,
#   'recurs': False,
#   'inoper': False,
#   'hertz01fwl': False,
#   '13812266198': False,
#   '170238151230': False,
#   'maring': False,
#   'ana': False,
#   '150xxxxxx06': False,
#   'ibicard': False,
#   'vis': False,
#   '227388': False,
#   '1310158159': False,
#   'macajub': False,
#   'alert': False,
#   'serv': False,
#   'disk': False,
#   'spac': False,
#   'streaming0sitehostingcombr': False,
#   '108163176170': False,
#   'devmd2': False,
#   'used': False,
#   '85': False,
#   'event': False,
#   'registred': False,
#   'sat': False,
#   'may': False,
#   '25': False,
#   'err': False,
#   '592': False,
#   '4479': False,
#   'post': False,
#   'apiattendanc': False,
#   'statuserrorcodeerrnoetimedoutcodeetimedoutsyscallconnectaddress1042021942port80': False,
#   '131021723': False,
#   'bras': False,
#   'httpfotosmsxyzcdi5embmrjm0f': False,
#   'wwwbbrasildesbloqueiocomjxxrgro8': False,
#   'wwwbbrasildesbloqueiocommifzpak7': False,
#   'isproalnetindisponi': False,
#   '138992229': False,
#   '20181217': False,
#   '160349': False,
#   '12010268': False,
#   'th': False,
#   'uttaradit': False,
#   'leandr': False,
#   '085xxxxxx08': False,
#   'alt': False,
#   'brasil': False,
#   'oti': False,
#   'statu': False,
#   'ip1682271268': False,
#   'dav': False,
#   '145xxxxxx37': False,
#   'gislenecpf': False,
#   '067xxxxxx95': False,
#   '01092010': False,
#   'r1300': False,
#   'top': False,
#   'target': False,
#   'selecion': False,
#   'cv': False,
#   'vag': False,
#   'promot': False,
#   'vend': False,
#   'entrev': False,
#   'amanha0111': False,
#   '1430hsshop': False,
#   'downtown': False,
#   'bl': False,
#   '10': False,
#   'sal': False,
#   '204b': False,
#   'tijuc': False,
#   '13122117174': False,
#   'popmangueirinhamktccr1036': False,
#   '11111278': False,
#   'oct': False,
#   '7': False,
#   '141325': False,
#   'manag': False,
#   'numb': False,
#   'nim028574628': False,
#   'reported': False,
#   'bgp5bgpstatechangedl': False,
#   '10064337': False,
#   'stat': False,
#   'is': False,
#   'changed': False,
#   'established': False,
#   '12': False,
#   'atualiz': False,
#   'celul': False,
#   'cadastr': False,
#   '11986275080': False,
#   '08022018': False,
#   'tinyurlcomy94o8kly': False,
#   'de': False,
#   'barb': False,
#   'we': False,
#   'are': False,
#   'waiting': False,
#   'decision': False,
#   'pleas': False,
#   'check': False,
#   'and': False,
#   'reply': False,
#   'befor': False,
#   'the': False,
#   'seat': False,
#   'gon': False,
#   '12goas': False,
#   '16416320468': False,
#   'guarapar': False,
#   'delci': False,
#   '160xxxxxx68': False,
#   '1459014': False,
#   'cels': False,
#   '124xxxxxx98': False,
#   'angel': False,
#   '029xxxxxx71': False,
#   'celsocpf': False,
#   '122xxxxxx78': False,
#   '26112003': False,
#   'r1200': False,
#   'sistem': False,
#   'aind': False,
#   'nao': False,
#   '1809vanguard': False,
#   '168xxxxxx19': False,
#   '15223317946': False,
#   'recif': False,
#   '050003d70201f': False,
#   '131100198254': False,
#   'dor': False,
#   'david': False,
#   '140xxxxxx40': False,
#   'colomb': False,
#   '1048134': False,
#   'arozi': False,
#   'httpfotosmsxyzcdi5nrwyqgdty': False,
#   'amazon': False,
#   'temp': False,
#   'ped': False,
#   'codig': False,
#   '118hernandespe696': False,
#   '251979': False,
#   'pront': False,
#   '21533': False,
#   '642kg': False,
#   'webglas': False,
#   '087629x': False,
#   '11984286501': False,
#   'httpbbdigitalmob': False,
#   'httpvuxsmssantandercom5511987584289': False,
#   '1201325316': False,
#   'cn': False,
#   'beijing': False,
#   'httpfotosmsxyzcdi1wwzhroa1v': False,
#   '138xxxxxx50': False,
#   'gpscnpj': False,
#   '11589xxxxxxx60propost': False,
#   'r59201': False,
#   'hostnet': False,
#   'domini': False,
#   '100fiocom': False,
#   'exp': False,
#   '2308': False,
#   'providenci': False,
#   'renovaca': False,
#   'imediat': False,
#   'painel': False,
#   'control': False,
#   'fcnpj': False,
#   '10267xxxxxxx97propost': False,
#   'r88121': False,
#   '16818150204': False,
#   'curitib': False,
#   'wwwbbrasildesbloqueiocom3fdqlm3q': False,
#   '152241139119': False,
#   'joinvill': False,
#   '4cnpj': False,
#   '07099xxxxxxx07propost': False,
#   'r5112': False,
#   'mirian': False,
#   'httpfotosmsxyzcdi1nqeuqgand': False,
#   'wwwbbrasildesbloqueiocompemyyf9': False,
#   'west': False,
#   'augustapucriobr': False,
#   'permanec': False,
#   'wwwbbrasildesbloqueiocombi96r9w0': False,
#   'energ': False,
#   'salt': False,
#   'riopedras1001001629': False,
#   'ip1001001629': False,
#   'wwwbbrasildesbloqueiocomyhww83e': False,
#   'wwwbbrasildesbloqueiocom7c23wbq2': False,
#   'adalbert': False,
#   '110xxxxxx84': False,
#   'cattan': False,
#   'ibi': False,
#   '243208': False,
#   '9010centr': False,
#   'globenet': False,
#   '13804044': False,
#   '52320': False,
#   '6': False,
#   'bgpsessionglobenet': False,
#   'felix': False,
#   '044xxxxxx01': False,
#   'gerald': False,
#   '098xxxxxx71': False,
#   'subestaca': False,
#   'morr': False,
#   'sulguarany2': False,
#   'statusprobl': False,
#   'detalh': False,
#   'pingstatu': False,
#   '0': False,
#   'dat': False,
#   '20190225': False,
#   'hor': False,
#   '083354': False,
#   '1681811366': False,
#   '050003430201f': False,
#   '131728615': False,
#   'sebast': False,
#   '152237245109': False,
#   'itatia': False,
#   'marc': False,
#   '162xxxxxx54': False,
#   'wwwbbrasildesbloqueiocomzkikya0b': False,
#   'mar': False,
#   '043xxxxxx64': False,
#   '060804f7b40301comunic': False,
#   'protest': False,
#   'gleyson': False,
#   'marqu': False,
#   'dexx': False,
#   '004345xxx99': False,
#   'titul': False,
#   '1091': False,
#   'chequ': False,
#   'comunic': False,
#   'apo': False,
#   'httpfotosmsxyzcdi6eb7ks6sn6': False,
#   'thil': False,
#   'security': False,
#   'notification': False,
#   'mailchimp': False,
#   'rik': False,
#   'comic': False,
#   'shop': False,
#   'not': False,
#   'loginip': False,
#   '14310725218': False,
#   'sp': False,
#   'bra': False,
#   'ts': False,
#   'sensor': False,
#   'ama': False,
#   '46': False,
#   'poa': False,
#   'seri': False,
#   'offlin': False,
#   'dest': False,
#   '20181103': False,
#   '235904': False,
#   '138361076': False,
#   'pingaliv': False,
#   '16823214108': False,
#   'casca': False,
#   'httpunicredmobiappacessocombr': False,
#   'miriamcnpj': False,
#   '00989xxxxxxx77propost': False,
#   'r18037': False,
#   '050003670201f': False,
#   '13894176203': False,
#   'agu': False,
#   'lind': False,
#   'wwwbbrasildesbloqueiocomwlpwhu6q': False,
#   'gruppen': False,
#   'cor': False,
#   '1121635529': False,
#   'country': False,
#   'kore': False,
#   'republic': False,
#   'of': False,
#   'aluizi': False,
#   '058xxxxxx63': False,
#   'inat': False,
#   'vsc1': False,
#   '201107': False,
#   '13125512496': False,
#   '4606': False,
#   'ola': False,
#   'const': False,
#   'pag': False,
#   'fatur': False,
#   '10083894inf': False,
#   'set': False,
#   'fibr': False,
#   'iur': False,
#   'ednald': False,
#   '139xxxxxx60': False,
#   'adiel': False,
#   '102xxxxxx04': False,
#   '377578': False,
#   'respond': False,
#   'cust': False,
#   'oceanoverseawebcombr': False,
#   '13812818110': False,
#   'at': False,
#   '08': False,
#   '2019': False,
#   '0532': False,
#   'am': False,
#   'request': False,
#   'timeout': False,
#   '1044422127': False,
#   'wwwbbrasildesbloqueiocomd5bp54xh': False,
#   '168023361': False,
#   'pesso': False,
#   'basil': False,
#   '097xxxxxx54': False,
#   '1681971522': False,
#   'capita': False,
#   'poc': False,
#   'wwwbbrasildesbloqueiocomb8qwpqx': False,
#   '432': False,
#   '4091': False,
#   'statuserrorcodeerrnoetimedoutcodeetimedoutsyscallconnectaddress1042021842port80': False,
#   '1681815815': False,
#   'jipar': False,
#   '0500032906062208': False,
#   'davidbennetthallcouk': False,
#   'elian': False,
#   '074xxxxxx30': False,
#   '17023347241': False,
#   'dour': False,
#   '160xxxxxx10': False,
#   '526004': False,
#   'immercpf': False,
#   '114xxxxxx64': False,
#   '26082012': False,
#   'r800': False,
#   '138972209': False,
#   'bertiog': False,
#   'wwwbbrasildesbloqueiocomrz6r9jap': False,
#   '0500034a0201f': False,
#   '170150225242': False,
#   'ferraz': False,
#   '050003500201f': False,
#   '16822890129': False,
#   'varze': False,
#   'pau': False,
#   'wwwbbrasildesbloqueiocom49av9893': False,
#   '036xxxxxx07': False,
#   'troc': False,
#   '18045095': False,
#   'loid': False,
#   'mai': False,
#   'roch': False,
#   'tiburci': False,
#   'silv': False,
#   '940039600': False,
#   'rua': False,
#   'isnard': False,
#   'josã©': False,
#   'sacch': False,
#   '56': False,
#   'bairr': False,
#   'recant': False,
#   'cosmã³polil': False,
#   '100642894': False,
#   'prez': False,
#   'cancel': False,
#   'sm': False,
#   'token': False,
#   'sincroniz': False,
#   'diret': False,
#   'canal': False,
#   'httpsgooglvps5vv': False,
#   'bitnuvemcom': False,
#   'identific': False,
#   '13859184245': False,
#   '2808': False,
#   '1556': False,
#   '141148': False,
#   'wwwbbrasildesbloqueiocomjv2g3g38': False,
#   'hostswitch': False,
#   'huaw': False,
#   '6720': False,
#   'consorci': False,
#   'eunapolil': False,
#   '10064033': False,
#   '3': False,
#   '000043': False,
#   'statusdown': False,
#   '152251197145': False,
#   '170244199161': False,
#   'baruer': False,
#   'wwwbbrasildesbloqueiocom2o0o8oxk': False,
#   '13821921230': False,
#   '1311967779': False,
#   'mococ': False,
#   'popalcantaramktrb2011': False,
#   '11111288': False,
#   '18': False,
#   '125803': False,
#   'registr': False,
#   'anorm': False,
#   'revej': False,
#   'dad': False,
#   'httpsappcelularmobibbcli': False,
#   'wwwbbrasildesbloqueiocom9pvdppsb': False,
#   '1244124056': False,
#   'np': False,
#   'kathmandu': False,
#   '131031161': False,
#   'maca': False,
#   '1382048980': False,
#   'sant': False,
#   'branc': False,
#   '13859192234': False,
#   '13836230110': False,
#   'luz': False,
#   '131196149202': False,
#   'bel': False,
#   'jardim': False,
#   'wwwbbrasildesbloqueiocom1ysjr7': False,
#   'antoni': False,
#   '080xxxxxx15': False,
#   '153855': False,
#   'host': False,
#   'rb§bicang': False,
#   '17024423114': False,
#   '20190705': False,
#   '050517': False,
#   'bloque': False,
#   'en': False,
#   'httpicloudsercureservercom17370': False,
#   '16890322': False,
#   'mont': False,
#   'alegr': False,
#   'minut': False,
#   'hdi': False,
#   'encaminh': False,
#   'marcelo10831sescsccombr': False,
#   'wwwbbrasildesbloqueiocomxmtz15dl': False,
#   '0500033b0201f': False,
#   '168194166130': False,
#   'ja': False,
#   'ncnpj': False,
#   '02279xxxxxxx74propost': False,
#   'r12298': False,
#   'httpglxsmssantandercom5511985814519': False,
#   'claudem': False,
#   '149xxxxxx54': False,
#   '0500037a0201f': False,
#   '1381227856': False,
#   'coronel': False,
#   'eze': False,
#   'laerci': False,
#   'laerciosponchiadovalfilmamcombr': False,
#   'condomini': False,
#   'vist': False,
#   'verific': False,
#   'lix': False,
#   'eletron': False,
#   '1702336431': False,
#   'osvald': False,
#   'cruz': False,
#   'wwwbbrasildesbloqueiocomackv21xj': False,
#   'eroscnpj': False,
#   '03452xxxxxxx10propost': False,
#   'r42381': False,
#   'wwwbbrasildesbloqueiocomh1dptiur': False,
#   'mois': False,
#   '090xxxxxx40': False,
#   '124127': False,
#   '167250191160': False,
#   '168194202138': False,
#   'cedr': False,
#   'linksulintlink2500mb': False,
#   '165509': False,
#   '16724995245': False,
#   '17024420448': False,
#   'feir': False,
#   '168197206169': False,
#   'juiz': False,
#   '050003670504ag': False,
#   'contact': False,
#   'recruitmentellivecom': False,
#   'if': False,
#   'you': False,
#   'hav': False,
#   'any': False,
#   'q': False,
#   '143255252139': False,
#   'ipating': False,
#   'pingdomalert': False,
#   'up': False,
#   'cl8': False,
#   'job': False,
#   'secgroup': False,
#   '10720173102': False,
#   'again': False,
#   '24012019': False,
#   '184754': False,
#   'downtim': False,
#   '39m': False,
#   'httpfotosmsxyzcdi2krnrrme5b': False,
#   'anselmocpf': False,
#   '069xxxxxx44': False,
#   '22082013': False,
#   'linksultelecom': False,
#   '095546': False,
#   '152250209239': False,
#   'carapicuib': False,
#   '050003050201appl': False,
#   '5c': False,
#   '16gb': False,
#   'imei358211': False,
#   'prox': False,
#   'cidad': False,
#   'httpsbrlcloudcomidx0rj': False,
#   'exat': False,
#   'ap': False,
#   'apr': False,
#   '21': False,
#   '020041': False,
#   'ispbenoitindisponi': False,
#   '138992314': False,
#   '20181009': False,
#   '225945': False,
#   '1430167254': False,
#   'lago': False,
#   '170150244': False,
#   'luiz': False,
#   'ferr': False,
#   'tôrr': False,
#   'realiz': False,
#   'extranet': False,
#   'utiliz': False,
#   '13122197178': False,
#   '05092018': False,
#   '095541hr': False,
#   '1001261249': False,
#   'mcnpj': False,
#   '09168xxxxxxx01propost': False,
#   'r699702': False,
#   '1382042536': False,
#   'daniel': False,
#   '057xxxxxx32': False,
#   '1065777': False,
#   '1100fiberbprbommtempoinfbr': False,
#   'aug152018': False,
#   '030249': False,
#   '0500032d0201f': False,
#   '1681816210': False,
#   'wwwbbrasildesbloqueiocomyh31kkbz': False,
#   'paulin': False,
#   'httpfotosmsxyzcdi5yxyiqhpfc': False,
#   'httpauthdentitymrcadolivrecombrmlbaccountidentityotp': False,
#   'boa': False,
#   'tard': False,
#   'encontr': False,
#   'ar': False,
#   'peç': False,
#   'comprov': False,
#   'financeironovanetrjcombr': False,
#   'nom': False,
#   'cibel': False,
#   '144xxxxxx26': False,
#   '13110887120': False,
#   'barr': False,
#   '143023234': False,
#   'guarulh': False,
#   ...})

# %%
tamanho_base_teste = len(frases_teste)
quantida_erros = len(erros)

porcentagem_erros = (quantida_erros * 100) / tamanho_base_teste
porcentagem_acertos = 100 - porcentagem_erros

print("O algoritmo classificou {:.4}% das frases corretamente".format(porcentagem_acertos))
print("O algoritmo classificou {:.4}% das frases incorretamente".format(porcentagem_erros))
# Out:
# O algoritmo classificou 98.42% das frases corretamente
# O algoritmo classificou 1.583% das frases incorretamente

# %% [markdown]
# ### 5.1.Matriz de confusão

# %% [markdown]
# Outra forma de visualização de erros e acertos é a construção da matriz de confusão:
#
# - Importamos o pacote do ```nltk``` com a função da matriz de confusão.
# - Criamos duas listas, uma com o resultado ```esperado``` e outra com o resultado ```previsto```, sendo que o esperado é o resultado desejado como resposta, e o previsto é de fato a classificação realizada.
# - A saída do algoritmo mostra uma matriz com linhas que representam o esperado e colunas que representam o previsto.
# - A diagonal principal indica a quantidade de acertos de cada classe.
#
# Esses resultados apresentam as classes que o algoritmo está mais errando e/ou acertando. Assim, é possível tomar decisões para melhorar a implementação da base de dados, bem como alguns parâmetros de otimização do algoritmo.

# %%
from nltk.metrics import ConfusionMatrix

# %%
esperado = []
previsto = []
for (frase, classe) in frases_teste:
    resultado = classificador.classify(frase)
    previsto.append(resultado)
    esperado.append(classe)

matriz = ConfusionMatrix(esperado, previsto)
print(matriz)
# Out:
#         |   b     |
#         |   l     |
#         |   o     |
#         |   c     |
#         |   k     |
#         |   e   o |
#         |   d   k |
# --------+---------+
# blocked |<301> 12 |
#      ok |   7<880>|
# --------+---------+
# (row = reference; col = test)

# %% [markdown]
# # 6.Revalidar o algoritmo de treino aplicando validação cruzada

# %% [markdown]
# Como a acurácia foi bastante alta, precisamos revalidar o algoritmo de treino com validação cruzada para garantir que não há um viés específico da base de treino devido a separação aleatória realizada pela função train_test_split. Como a biblioteca NLTK não tem suporte direto para cross validation, vamos realizar o processo manualmente.

# %%
dados_kfold = carregar_dados(dados)

# %%
base_kfold = estruturar_dados(dados_kfold)

# %%
lista_acurácia = []
num_folds = 10
tamanho_fold = int(len(base_kfold)/num_folds)
for i in range(num_folds):
    teste = base_kfold[i*tamanho_fold:][:tamanho_fold]
    treino = base_kfold[:i*tamanho_fold] + base_kfold[(i+1)*tamanho_fold:]
    
    classificador = nltk.NaiveBayesClassifier.train(treino)
    acurácia = nltk.classify.accuracy(classificador, teste)*100
    print("A acurácia da classificação da base teste {} é de {:.4}%".format(i + 1, acurácia))
    lista_acurácia.append(acurácia)
# Out:
# A acurácia da classificação da base teste 1 é de 49.83%
# A acurácia da classificação da base teste 2 é de 99.83%
# A acurácia da classificação da base teste 3 é de 81.0%
# A acurácia da classificação da base teste 4 é de 99.5%
# A acurácia da classificação da base teste 5 é de 83.83%
# A acurácia da classificação da base teste 6 é de 96.5%
# A acurácia da classificação da base teste 7 é de 93.83%
# A acurácia da classificação da base teste 8 é de 94.0%
# A acurácia da classificação da base teste 9 é de 97.0%
# A acurácia da classificação da base teste 10 é de 98.17%

# %%
import numpy as np

# %%
np.array(lista_acurácia).mean()
# Out:
# 89.35

# %% [markdown]
# A acurácia média do teste com validação cruzada K-Fold (k=10) foi de 89,35%, o que significa que não temos problemas de overfitting e podemos agora realizar o treino com a base completa.

# %% [markdown]
# # 6.Treino com a base completa

# %% [markdown]
# Como o modelo foi validado, podemos agora treiná-lo com a base de treino original completa.

# %%
base_treino = carregar_dados(dados)

# %%
len(base_treino)
# Out:
# 6000

# %%
base_final = estruturar_dados(base_treino)

# %%
# %%time
# Cria o classificador (tabela de probabilidade) com base no conjunto de treinamento
classificador = nltk.NaiveBayesClassifier.train(base_final)
# Out:
# Wall time: 1min 30s

# %%
# Retorna as classes da base de dados (ok, blocked)
print(classificador.labels())
# Out:
# ['blocked', 'ok']

# %%
# Retorna os 10 atributos mais significativos
print(classificador.show_most_informative_features(10))
# Out:
# Most Informative Features
#                       bb = True           blocke : ok     =   1778.2 : 1.0
#                      fot = True           blocke : ok     =    396.8 : 1.0
#                       br = True               ok : blocke =    314.7 : 1.0
#                        j = True           blocke : ok     =    266.9 : 1.0
#                    debit = True               ok : blocke =    208.2 : 1.0
#                  prezado = True           blocke : ok     =    192.9 : 1.0
#                    local = True           blocke : ok     =    166.9 : 1.0
#                    login = True               ok : blocke =    121.9 : 1.0
#                    aplic = True               ok : blocke =    104.2 : 1.0
#                      lig = True               ok : blocke =    100.0 : 1.0
# None

# %% [markdown]
# # 7.Salvar o modelo criado para aplicar em novos dados

# %%
import pickle

# %%
def salvar_modelo(modelo, nome_arquivo):
    nome = str(nome_arquivo) + ".pickle"
    try:
        salvar_modelo = open(nome,"wb")
        pickle.dump(modelo, salvar_modelo)
        salvar_modelo.close()
        return True
    except Exception as e:
        return e

# %%
if salvar_modelo(classificador,'naivebayes'):
    print("Modelo salvo para ser utilizado no futuro")
# Out:
# Modelo salvo para ser utilizado no futuro

# %%
print("Tempo total para executar esse notebook foi de {} segundos".format(time() - ti))
# Out:
# Tempo total para executar esse notebook foi de 1202.9029409885406 segundos
